# %%
import googleapiclient.discovery
import pymongo
import pymysql
import pandas as pd
import mysql.connector
import cryptography
import streamlit as st

# %%
api_key = "AIzaSyDeNGdSiAyKWkvHmKZzNZb3yT0_xN3PmAg"
api_service_name = "youtube"
api_version = "v3"
youtube = googleapiclient.discovery.build(api_service_name, api_version,developerKey = api_key)

# %%
def get_channel_details(c_id):
     request=youtube.channels().list(
       part="snippet,contentDetails,statistics",
       id=c_id
)
     channel_response = request.execute()
     
     for i in channel_response['items']:
           data = dict(channel_name=i['snippet']['title'],
                channel_id=i['id'],
                subscribers=i['statistics']['subscriberCount'],
                channel_views=i['statistics']['viewCount'],
                Total_videos=i['statistics']['videoCount'],
                Description=i['snippet']['description'],
                playlist_id=i['contentDetails']['relatedPlaylists']['uploads']
                )
     return data

# %%
channel_data = get_channel_details("UCnz-ZXXER4jOvuED5trXfEA")
channel_data
# Out:
# {'channel_name': 'techTFQ',
#  'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#  'subscribers': '280000',
#  'channel_views': '15059567',
#  'Total_videos': '119',
#  'Description': 'Hi, I am Thoufiq! On this channel, I teach SQL, Python and Database concepts in the field of Data Analytics and Data Science in the most simplest manner possible. If this excites you then do consider subscribing.\n\nYou will also find videos covering interview questions and also videos where I provide career guidance in the field of Data Analytics and Data Science which should help you find your dream job.\n\nI aim to make techTFQ a go to YouTube channel for anyone learning SQL, Python and Databases in the field of Data Analytics and Data Science.\n\nThank you for begin here :)\n',
#  'playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'}

# %%
def get_video_ids(c_id):
    video_ids=[]
    response = youtube.channels().list(id=c_id,
                                    part='contentDetails').execute()
    playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page = None
    while True:
        video_response = youtube.playlistItems().list(
                                    part='snippet',
                                    playlistId=playlist_id,
                                    maxResults=50,
                                    pageToken=next_page).execute()
        for i in range(len(video_response['items'])):
            video_ids.append(video_response['items'][i]['snippet']['resourceId']['videoId'])
        next_page=video_response.get('nextPageToken')
        if next_page is None:
            break
    return video_ids

# %%
v_id=get_video_ids('UCnz-ZXXER4jOvuED5trXfEA')

# %%
v_id
# Out:
# ['ka9kDqkITX4',
#  'WBqTj-FYux8',
#  '78DNY36XxQw',
#  'KrUIQAcFptY',
#  'LBWXjtLNauQ',
#  'oU8fhP17ozk',
#  'o5W-iAK21ws',
#  'Xx09nRpwEtU',
#  '0w5mx6lfx1Y',
#  'dgIYeUAOzbM',
#  'DKYg8JahHI0',
#  'RjZFC6NVUMc',
#  'w67I_aPKygE',
#  'rM1BVoBke04',
#  'FRzbOb3jdLg',
#  'CVSfxxAun-4',
#  'tY4POdOldQM',
#  'J_da4WKsrjE',
#  'AZ29DXaJ1Ts',
#  'ZML_EJrBhnY',
#  '6lI0q2DV8DY',
#  'nzJJP-uDIZc',
#  'BNmoCYk58mU',
#  'W5Wvyc9Pass',
#  'oedv5lR3w_g',
#  'HiscSRv7zWk',
#  'PLN28d0PoFU',
#  'GxmrInUIMAE',
#  'D0-Qy7yk5TQ',
#  'GHtX0QXfi6g',
#  '0QcEqFrhb_Y',
#  'smztq8sRAhk',
#  '7skZzocEU6c',
#  'LZGaRcDxj8I',
#  'rBPQ5fg_kiY',
#  'hvwltYazuQo',
#  'a-hFbr-4VQQ',
#  'pMNcPLc9Z7c',
#  'zZKb8FQRShs',
#  'jS5_hjFgfzA',
#  '6UAU79FNBjQ',
#  'ZwFfiadQB3k',
#  'Det4ZjBSe3M',
#  'xUsY2jWQa1w',
#  'ueOUSjdAZY8',
#  '90iK6gGvG_g',
#  'hsaPfEvForM',
#  'jb8XlF2dkoY',
#  'WhkNQ3g0U64',
#  '_suB8xV9aPc',
#  'dWHSt0BVlv0',
#  'xJVWL7eMir0',
#  'h48xzQR3wNQ',
#  'S5gX-LLAZIM',
#  'LNlzx-YX8rI',
#  'WzkBZ0byoYE',
#  'weCZ1WynbMI',
#  '3dOxGYkpVbE',
#  '9dLXZrw6nac',
#  'i3xK7Nc414Q',
#  'H7YMumanHBA',
#  '4p-G7fGhqRk',
#  'yLR1w4tZ36I',
#  '-DiOp9vAEuM',
#  'O1o9m9T1c3k',
#  '7hZYh9qXxe4',
#  'aE623ff7zkM',
#  'eXJGjbDo5KY',
#  'O52sweYbCyI',
#  'cLSxasHg9WY',
#  'l6XhSFAyvO0',
#  'nJIEIzF7tDw',
#  'RehbnzKHS28',
#  '0OQJDd3QqQM',
#  'V6KPbGLYL4A',
#  'OIqm909GYYo',
#  'xN2PRAd8IZQ',
#  'AK7_m-aThfw',
#  'CYszyA2Xzdg',
#  'wT9ICgxRPYY',
#  'XruOBp7yPXU',
#  'SwSbnmqk3zY',
#  '8p_OzqIJ_p4',
#  '0Hhqf8L-b_0',
#  'M2NzvnfS-hI',
#  'QNfnuK-1YYY',
#  'PuBadaR8qC4',
#  'FNYdBLwZ6cE',
#  'zAmJPdZu8Rg',
#  'HJAwAKwFX-A',
#  'kY5HtrkjSj0',
#  'LCVSmkyB4v8',
#  '6x7vHXfRAP0',
#  '-DrSbc8B0WI',
#  'gsa1oFn9n0M',
#  'Ww71knvhQ-s',
#  'Jsnw6HLASZA',
#  'V_BozMwoYe4',
#  '0wjPsKDrYt8',
#  '1-z9ptlBar4',
#  '35dXEQJkFE8',
#  'jgNB4GN1UaQ',
#  'fhxByMe0mq8',
#  '5bwpXLHzZRo',
#  'UzOnFDmoJ9w',
#  'HNChkuE6HyA',
#  '2gFqUWO-AWM',
#  'NvdSKgQcyuc',
#  'BBb_duZIusU',
#  'PRGkYivK2xI',
#  'M323OL6K5vs',
#  'i7BjHjRafU8',
#  'r2asdRpr3uw',
#  'Hl4NZB1XR9c',
#  '1aybOgni7lI',
#  'j09EQ-xlh88',
#  '7nzTDrio7vY',
#  'J-uCLHTIWZ4',
#  '_BMPh5M4BIY']

# %%
def get_video_details(V_ID):
    video_data=[]
    for video_id in V_ID:
        v_request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        v_response=v_request.execute()
        for item in v_response["items"]:
                                    data=dict(
                                            Video_Id=item['id'],
                                            Vide_name=item['snippet']['title'],
                                            Tags=item['snippet'].get('tags'),
                                            Description=item['snippet'].get('description'),
                                            PublishedAt=item['snippet']['publishedAt'],
                                            Thumbnail=item['snippet']['thumbnails']['default']['url'],
                                            Duration=item['contentDetails']['duration'],
                                            Views_count=item['statistics'].get('viewCount'),
                                            Likes_count=item['statistics'].get('likeCount'),
                                            Comments_count=item['statistics'].get('commentCount'),
                                            Favorite_Count=item['statistics']['favoriteCount'],
                                            Definition=item['contentDetails']['definition'],
                                            Caption_Status=item['contentDetails']['caption']
                                            )
                                    video_data.append(data)    
    return video_data

# %%
v_details = get_video_details(v_id)

# %%
v_details
# Out:
# [{'Video_Id': 'ka9kDqkITX4',
#   'Vide_name': 'SQL Interview Problem no 15 | #30DaySQLQueryChallenge | Solving SQL Queries',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the 15th video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-15\n\nTimeline:\n00:00 Intro\n00:30 Understanding Problem Statement \n01:42 Solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-15T13:00:07Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/ka9kDqkITX4/default.jpg',
#   'Duration': 'PT15M57S',
#   'Views_count': '1471',
#   'Likes_count': '99',
#   'Comments_count': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'WBqTj-FYux8',
#   'Vide_name': 'SQL Interview Queries #14 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the FOURTEENTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-14\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n01:34 Solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-14T18:38:39Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/WBqTj-FYux8/default.jpg',
#   'Duration': 'PT8M52S',
#   'Views_count': '2211',
#   'Likes_count': '136',
#   'Comments_count': '26',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '78DNY36XxQw',
#   'Vide_name': 'SQL Interview Queries #13 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the THIRTEENTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-13\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n00:37 Solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-13T13:13:22Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/78DNY36XxQw/default.jpg',
#   'Duration': 'PT6M58S',
#   'Views_count': '2942',
#   'Likes_count': '162',
#   'Comments_count': '43',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'KrUIQAcFptY',
#   'Vide_name': 'SQL Interview Queries #12 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the TWELVE video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-12\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n02:02 Solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-12T15:02:52Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/KrUIQAcFptY/default.jpg',
#   'Duration': 'PT21M',
#   'Views_count': '3966',
#   'Likes_count': '172',
#   'Comments_count': '27',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'LBWXjtLNauQ',
#   'Vide_name': 'SQL Interview Queries #11 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the ELEVENTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-11\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n03:02 Solution to the SQL Problem\n06:40 Quick understanding of SQL Frame Clause\n10:27 Continue with the solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-11T13:31:53Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/LBWXjtLNauQ/default.jpg',
#   'Duration': 'PT14M49S',
#   'Views_count': '3600',
#   'Likes_count': '180',
#   'Comments_count': '31',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'oU8fhP17ozk',
#   'Vide_name': 'SQL Interview Queries #10 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the TENTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-10\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n00:59 Solution to the SQL Problem in PostgreSQL\n14:47 Solution to the SQL Problem in Microsoft SQL Server\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-10T14:10:43Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/oU8fhP17ozk/default.jpg',
#   'Duration': 'PT17M41S',
#   'Views_count': '4468',
#   'Likes_count': '204',
#   'Comments_count': '23',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'o5W-iAK21ws',
#   'Vide_name': 'SQL Interview Queries #9 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the NINTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-9\n\nTimeline:\n00:00 Intro\n00:18 Understanding Problem Statement \n03:40 Solution to the SQL Problem\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-09T13:30:07Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/o5W-iAK21ws/default.jpg',
#   'Duration': 'PT8M54S',
#   'Views_count': '4214',
#   'Likes_count': '192',
#   'Comments_count': '24',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'Xx09nRpwEtU',
#   'Vide_name': 'SQL Interview Queries #8 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the EIGHTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-8\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n02:34 Solution no 1 \n09:10 Solution no 2\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-08T15:09:59Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/Xx09nRpwEtU/default.jpg',
#   'Duration': 'PT17M12S',
#   'Views_count': '4341',
#   'Likes_count': '204',
#   'Comments_count': '46',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '0w5mx6lfx1Y',
#   'Vide_name': 'SQL Interview Queries #7 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the SEVENTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-7\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n02:53 Solution in PostgreSQL\n12:39 Solution in Microsoft SQL Server\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-07T14:33:09Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/0w5mx6lfx1Y/default.jpg',
#   'Duration': 'PT18M30S',
#   'Views_count': '5446',
#   'Likes_count': '230',
#   'Comments_count': '33',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'dgIYeUAOzbM',
#   'Vide_name': 'SQL Interview Queries #6 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the SIXTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-6\n\nTimeline:\n00:00 Intro\n00:16 Understanding Problem Statement \n02:55 Solution - Ouput 1\n07:48 Solution - Ouput 2\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-06T13:27:08Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/dgIYeUAOzbM/default.jpg',
#   'Duration': 'PT9M34S',
#   'Views_count': '5501',
#   'Likes_count': '318',
#   'Comments_count': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'DKYg8JahHI0',
#   'Vide_name': 'SQL Interview Queries #5 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the FIFTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-5\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement \n02:30 Solution - Populate Employee Transaction table\n11:40 Solution - Generate report in PostgreSQL\n25:33 Solution - Generate report in Microsoft SQL Server\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-05T16:26:48Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/DKYg8JahHI0/default.jpg',
#   'Duration': 'PT30M36S',
#   'Views_count': '7160',
#   'Likes_count': '275',
#   'Comments_count': '33',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'RjZFC6NVUMc',
#   'Vide_name': 'SQL Interview Queries #4 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the FOURTH video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-4\n\nTimeline:\n00:00 Intro\n00:50 Understanding Problem Statement \n02:17 Solution\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-04T13:00:11Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/RjZFC6NVUMc/default.jpg',
#   'Duration': 'PT6M39S',
#   'Views_count': '6870',
#   'Likes_count': '401',
#   'Comments_count': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'w67I_aPKygE',
#   'Vide_name': 'SQL Interview Queries #3 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the THIRD video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\nThis video covers a SQL problem I found on Reddit.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-3\n\nTimeline:\n00:00 Intro\n00:10 Understanding Problem Statement Query2\n01:59 Solution no 1\n05:52 Solution no 2\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-03T13:00:10Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/w67I_aPKygE/default.jpg',
#   'Duration': 'PT16M39S',
#   'Views_count': '9828',
#   'Likes_count': '429',
#   'Comments_count': '61',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'rM1BVoBke04',
#   'Vide_name': 'SQL Interview Queries #2 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the SECOND video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. I will explain how to solve and address such SQL queries during interviews in these videos.\nThis video covers a REAL SQL Interview query that was shared by my subscriber in an email.\n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-2\n\nTimeline:\n00:00 Intro\n00:23 Understanding Problem Statement Query2\n08:27 Solution to the Query1\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-02T13:30:07Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/rM1BVoBke04/default.jpg',
#   'Duration': 'PT29M18S',
#   'Views_count': '15873',
#   'Likes_count': '756',
#   'Comments_count': '77',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'FRzbOb3jdLg',
#   'Vide_name': 'SQL Interview Queries #1 | #30DaySQLQueryChallenge | Solving SQL Problems',
#   'Tags': ['sql',
#    'learnsql',
#    'sql query',
#    'sql queries',
#    'sql interview query',
#    'sql interview queries',
#    'sql interview problem',
#    'sql problem',
#    'sql interview',
#    'techtfq',
#    'sql techtfq',
#    '30daysqlquerychallenge',
#    'techtfq sql challenge'],
#   'Description': "30DaySQLQueryChallenge is a series of 30 videos covering 30 SQL Interview Queries. This is the first video in this series. This video series aims to provide 30 SQL Queries that can be asked during SQL Interviews. In these videos, I will explain how to solve and address such SQL queries during interviews.\nThis particular video covers an SQL Interview query that I found on Reddit. \n\nLet's follow the below routine to make the best use of it:\n1. Watch the YouTube video (first half) to understand the problem statement.\n\n2. Go to my discord server (link below), download the dataset for each problem, and try solving it yourself.\n\n3. Share your solution on Discord and discuss different solutions and issues on my Discord server.\n\n4. Watch the second half of my YouTube video to find my solution to the problem.\n\n5. Share it with your contacts and spread the knowledge.\n\n\nDOWNLOAD the Dataset from below:\nDiscord server: https://discord.gg/824u5tNtS3\nBlog website: https://techtfq.com/blog/30daysqlquerychallenge-query-1\n\nTimeline:\n00:00 Intro about the #30DaySQLQueryChallenge\n00:58 Problem Statement Query1\n05:43 #30DaySQLQueryChallenge Process to be followed\n07:16 Solution to the Query1\n\nThanks for participating in this challenge!\n\nGood luck and Happy Learning!",
#   'PublishedAt': '2024-03-01T13:30:11Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/FRzbOb3jdLg/default.jpg',
#   'Duration': 'PT19M59S',
#   'Views_count': '48381',
#   'Likes_count': '2697',
#   'Comments_count': '136',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'CVSfxxAun-4',
#   'Vide_name': 'How to clear Job Interviews? Job Interview Tips',
#   'Tags': ['job interview',
#    'job interview tips',
#    'how to clear job interview',
#    'hacks to to clear job interview',
#    'sql interview',
#    'data analyst interview',
#    'interview',
#    'interview hacks',
#    'interview tips'],
#   'Description': 'Watch the full video here: \nhttps://youtu.be/tY4POdOldQM',
#   'PublishedAt': '2024-02-11T09:00:14Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/CVSfxxAun-4/default.jpg',
#   'Duration': 'PT51S',
#   'Views_count': '4360',
#   'Likes_count': '280',
#   'Comments_count': '5',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'tY4POdOldQM',
#   'Vide_name': 'Job Interview Tips | Follow these steps to clear JOB INTERVIEWS | How to clear Job Interviews?',
#   'Tags': ['job interview',
#    'job interview tips',
#    'how to clear job interview',
#    'hacks to to clear job interview',
#    'sql interview',
#    'data analyst interview',
#    'interview',
#    'interview hacks',
#    'interview tips'],
#   'Description': "Follow the Job Interview tips mentioned in this video to clear any job interview. These tips or hacks can help you succeed in job interviews even when you fail to answer many questions.\n\nAs an active interviewer, I've come across many candidates who fail the interview because they are unaware of certain basic things you need to do to clear an interview. Hence in this video, I have gathered 6 points or tips or hacks that you should follow during an interview to give yourself the best chance to clear the interview even when you fail to answer most of the interview questions.\n\nThese are the tips I have followed in my career personally and have been able to clear interviews and get the job even when I failed to answer many questions but I succeeded because I did all the other things right and that is exactly what I have mentioned in this video.\n\nMy aim is to help candidates who are struggling to pass interviews. Hopefully, by following these 6 tips, you will be able to succeed.\n\nTimeline:\n00:00 Intro & Purpose\n00:43 Job Interview Tip 1\n02:58 Job Interview Tip 2\n04:43 Job Interview Tip 3\n06:10 Job Interview Tip 4\n08:18 Job Interview Tip 5\n09:30 Job Interview Tip 6\n10:39 Summary\n\nThank you for watching!\n\n\nWatch more videos:\n🔴 My Recommended courses 👇\n\n✅Complete Data Analytics Bootcamp:\nhttps://codebasics.io/bootcamps/data-analytics-bootcamp-with-practical-job-assistance?refId=ujxkeg5e-n948-4cpg-fx9g-q0fvzczdyp\n\n✅ Learn Power BI: \nhttps://codebasics.io/courses/power-bi-data-analysis-with-end-to-end-project?refId=4b1e1886-3252-4bf1-86f4-7d603dab692f\n\n✅ Learn complete SQL: \nhttps://learnsql.com/?ref=thoufiqmohammed\nhttps://techtfq.graphy.com/courses/Recordings-from-SQL-Bootcamp-64f0e1cae4b014d5beccb78e\n\n✅ Practice SQL Queries: \nhttps://www.stratascratch.com/?via=techTFQ\n\n✅ Learn Python: \nhttps://techtfq.graphy.com/courses/Python-Bootcamp-for-Beginners-64d0e0a2e4b067acf3a67a2b-64d0e0a2e4b067acf3a67a2b?buy=true\n\n\n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\n\nTHANK YOU,\nThoufiq | techTFQ",
#   'PublishedAt': '2024-02-08T13:00:08Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/tY4POdOldQM/default.jpg',
#   'Duration': 'PT11M15S',
#   'Views_count': '11146',
#   'Likes_count': '650',
#   'Comments_count': '45',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'J_da4WKsrjE',
#   'Vide_name': 'Solving SQL Interview Problem with MULTIPLE solutions | Practice SQL Queries',
#   'Tags': ['sql practice',
#    'sql queries',
#    'sql',
#    'learn sql',
#    'solving sql queries',
#    'solve sql problems',
#    'sql project',
#    'sql case study',
#    '20+ sql queries',
#    '20 sql queries',
#    'practice sql',
#    'sql interview queries',
#    'sql problems',
#    'sql techtfq',
#    'techtfq sql',
#    'techtfq',
#    'multiple solution sql problem',
#    'multiple solution sql query'],
#   'Description': 'In this video, we will solve an SQL interview problem by providing 6 different solutions. The ability to solve an SQL query using multiple solutions can help you to get better at SQL since you will be able to apply different concepts of SQL to solve the same problem and also it can be beneficial during interviews.\n\nDuring SQL interviews, it is very common for the interviewer to ask you to not not use a specific concept when solving a SQL query or you may be asked to provide multiple solutions to the same SQL problem hence this video will be a good example to practice solving SQL queries where you provide multiple different solutions to the same SQL problem.\n\nTimeline:\n00:00 Intro\n00:41 Understanding the SQL problem statement\n02:24 Solution 1\n07:10 Solution 2\n11:25 Solution 3\n12:39 Solution 4\n17:49 Solution 5\n21:10 Solution 6\n\nDownload the scripts, and dataset from the blog below:\nhttps://techtfq.com/blog/solving-sql-interview-problem-with-multiple-solutions\n\nThanks for watching!\n\n\nWatch more videos:\n🔴 My Recommended courses 👇\n\n✅Complete Data Analytics Bootcamp:\nhttps://codebasics.io/bootcamps/data-analytics-bootcamp-with-practical-job-assistance?refId=ujxkeg5e-n948-4cpg-fx9g-q0fvzczdyp\n\n✅ Learn Power BI: \nhttps://codebasics.io/courses/power-bi-data-analysis-with-end-to-end-project?refId=4b1e1886-3252-4bf1-86f4-7d603dab692f\n\n✅ Learn complete SQL: \nhttps://learnsql.com/?ref=thoufiqmohammed\nhttps://techtfq.graphy.com/courses/Recordings-from-SQL-Bootcamp-64f0e1cae4b014d5beccb78e\n\n✅ Practice SQL Queries: \nhttps://www.stratascratch.com/?via=techTFQ\n\n✅ Learn Python: \nhttps://techtfq.graphy.com/courses/Python-Bootcamp-for-Beginners-64d0e0a2e4b067acf3a67a2b-64d0e0a2e4b067acf3a67a2b?buy=true\n\n\n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq | techTFQ',
#   'PublishedAt': '2024-01-17T13:30:09Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/J_da4WKsrjE/default.jpg',
#   'Duration': 'PT23M38S',
#   'Views_count': '19225',
#   'Likes_count': '813',
#   'Comments_count': '65',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'AZ29DXaJ1Ts',
#   'Vide_name': 'SQL Project | SQL Case Study to SOLVE and PRACTICE SQL Queries | 20+ SQL Problems',
#   'Tags': ['sql practice',
#    'sql queries',
#    'sql',
#    'learn sql',
#    'solving sql queries',
#    'solve sql problems',
#    'sql project',
#    'sql case study',
#    '20+ sql queries',
#    '20 sql queries',
#    'practice sql',
#    'sql interview queries',
#    'sql problems',
#    'sql techtfq',
#    'techtfq sql',
#    'techtfq'],
#   'Description': 'In this video let us work on an SQL Case study in which we shall download a dataset from Kaggle and then upload it to a PostgreSQL database using Python.  We shall then analyze the data and solve 20+ SQL queries. You can term this SQL practice exercise as an SQL project or an SQL case study. The aim is to provide you with a dataset to analyze data and then practice basic to intermediate SQL problems. \n\nThe dataset we use is the famous paintings dataset taken from Kaggle. We use a simple Python script to upload data from CSV files to PostgreSQL database tables. We then use SQL queries to answer over 20 problems related to the famous paintings dataset.\n\nDownload the project material from my blog:\nhttps://techtfq.com/blog/sql-project-sql-case-study-to-solve-and-practice-sql-queries\n\nKaggle dataset link:\nhttps://www.kaggle.com/datasets/mexwell/famous-paintings\n\nTimestamp:\n00:00 Intro\n00:50 Download Kaggle Dataset\n01:27 Load data to Database using Python\n12:29 Analysing Kaggle Dataset\n16:01 Solving SQL Query no 1\n21:27 Solving SQL Query no 2\n27:46 Solving SQL Query no 3\n\nThank you for watching!\n\nWatch more videos:\n🔴 My Recommended courses 👇\n\n✅Complete Data Analytics Bootcamp:\nhttps://codebasics.io/bootcamps/data-analytics-bootcamp-with-practical-job-assistance?refId=ujxkeg5e-n948-4cpg-fx9g-q0fvzczdyp\n\n✅ Learn Power BI: \nhttps://codebasics.io/courses/power-bi-data-analysis-with-end-to-end-project?refId=4b1e1886-3252-4bf1-86f4-7d603dab692f\n\n✅ Learn complete SQL: \nhttps://learnsql.com/?ref=thoufiqmohammed\nhttps://techtfq.graphy.com/courses/Recordings-from-SQL-Bootcamp-64f0e1cae4b014d5beccb78e\n\n✅ Practice SQL Queries: \nhttps://www.stratascratch.com/?via=techTFQ\n\n✅ Learn Python: \nhttps://techtfq.graphy.com/courses/Python-Bootcamp-for-Beginners-64d0e0a2e4b067acf3a67a2b-64d0e0a2e4b067acf3a67a2b?buy=true\n\n\n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq | techTFQ',
#   'PublishedAt': '2024-01-09T13:00:17Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/AZ29DXaJ1Ts/default.jpg',
#   'Duration': 'PT34M53S',
#   'Views_count': '72190',
#   'Likes_count': '2460',
#   'Comments_count': '151',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'ZML_EJrBhnY',
#   'Vide_name': 'Top 10 SQL Interview Queries | Popular SQL Queries for SQL Interview',
#   'Tags': ['sql',
#    'learn sql',
#    'sql query',
#    'sql queries',
#    'top 10 sql queries',
#    'sql interview queries',
#    'sql problem',
#    'sql interview problem',
#    'best sql queries',
#    'most common sql queries',
#    'solve sql queries',
#    'practice sql queries',
#    'sql techtfq',
#    'techtfq sql',
#    'techtfq'],
#   'Description': 'In this video, we look at 10 commonly asked SQL Queries during interviews. These are in my opinion top 10 SQL queries to learn before going to any SQL Interview. These 10 queries will cover most of the important SQL concepts hence if you can solve these 10 queries then you would have a very good understanding of SQL.\n\nDownload all 10 SQL query scripts, solutions, and problem statements from my blog below:\nhttps://techtfq.com/blog/top-10-sql-interview-queries-popular-sql-queries-for-sql-interview\n\nCheck out one of the BEST platforms to learn SQL:\nhttps://learnsql.com/?ref=thoufiqmohammed\n\nGet yourself a "Certificate of Competency in SQL" for free from below:\nhttps://learnsql.com/sql-skill-assessment\n\nTimestamp:\n00:00 Intro\n01:03 Query 1\n04:25 Query 2\n07:34 LearnSQL\n09:34 Get your Free SQL Competence Certificate\n10:14 Query 3\n12:59 Query 4\n16:05 Query 5\n19:56 Query 6\n23:27 Query 7\n26:03 Query 8\n27:58 Query 9\n31:13 Query 10\n\nMore Videos:\nDelete Duplicate data (10 ways):\nhttps://www.youtube.com/watch?v=h48xzQR3wNQ\n\nWindow function Frame clause Tutorial:\nhttps://youtu.be/zAmJPdZu8Rg?si=Y4uGAI5a3kOzSMc1\n\nJOINS Tutorial (SELF Join)\nhttps://youtu.be/RehbnzKHS28?si=oAfkKtHEXccuuvHa\n\nRecursive SQL Tutorial:\nhttps://youtu.be/7hZYh9qXxe4?si=y6L4suXDdSZP24W1\n\nSubqueries Tutorial:\nhttps://youtu.be/nJIEIzF7tDw?si=YYKdSVz9r4TBodN2\n\nThanks for watching!\nThoufiq | techTFQ',
#   'PublishedAt': '2023-11-22T14:09:13Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/ZML_EJrBhnY/default.jpg',
#   'Duration': 'PT36M33S',
#   'Views_count': '129058',
#   'Likes_count': '3429',
#   'Comments_count': '158',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '6lI0q2DV8DY',
#   'Vide_name': 'SQL Cricket Match Problem | Solving SQL Interview Problem',
#   'Tags': ['sql',
#    'sql query',
#    'sql queries',
#    'solving sql query',
#    'sql interview questions and answers',
#    'sql interview questions',
#    'sql interview query',
#    'sql problem',
#    'practice sql queries',
#    'practice sql query',
#    'techtfq',
#    'techtfq sql',
#    'sql techtfq',
#    'learn sql',
#    'sql tutorial',
#    'sql practice',
#    'cricket match',
#    'cricket match sql'],
#   'Description': "In this video, let's solve an SQL interview problem related to a Cricket match.\nThis is a real SQL Query asked during a SQL Job Interview.\n\nThis is a good SQL problem to test out your SQL Query writing skills.\n\nThis video is sponsored by OdinSchool.\nOdinSchool Bootcamp link: https://hubs.la/Q024h4NC0\nSuccess stories page link: https://hubs.la/Q024h4Xz0\n\nDownload Dataset, SQL scripts for free from my blog below:\nhttps://techtfq.com/blog/sql-cricket-match-problem-solving-sql-interview-problem\n\nThanks for watching!\nThoufiq | techTFQ",
#   'PublishedAt': '2023-10-18T14:44:40Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/6lI0q2DV8DY/default.jpg',
#   'Duration': 'PT16M8S',
#   'Views_count': '21371',
#   'Likes_count': '883',
#   'Comments_count': '90',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'nzJJP-uDIZc',
#   'Vide_name': 'Solving an SQL Interview Problem | Find Child - Parent - Grandparent Hierarchy using SQL',
#   'Tags': ['sql',
#    'sql query',
#    'sql queries',
#    'solving sql query',
#    'sql interview questions and answers',
#    'sql interview questions',
#    'sql interview query',
#    'sql problem',
#    'practice sql queries',
#    'practice sql query',
#    'techtfq',
#    'techtfq sql',
#    'sql techtfq',
#    'learn sql',
#    'sql tutorial',
#    'sql practice'],
#   'Description': 'In this video, we will solve an SQL Interview problem where we need to find the child, parent, and grandparent hierarchy/relationship to arrive at the final result. The problem is very interesting and slightly confusing.\nThis is a good SQL problem to test out your SQL Query writing skills.\n\nThis video is sponsored by OdinSchool.\nOdinSchool Bootcamp link: https://hubs.la/Q024h4NC0\nSuccess stories page link: https://hubs.la/Q024h4Xz0\n\nDownload Dataset, SQL scripts for free from my blog below:\nhttps://techtfq.com/blog/solving-an-sql-interview-problem-find-child-parent-grandparent-hierarchy-using-sql\n\nTimelines:\n00:00 Intro\n00:20 Understanding the problem statement\n01:14 Analysing the given data\n04:36 OdinSchool Bootcamp promo\n06:20 Solution to the problem\n\nThanks for watching!\nThoufiq | techTFQ',
#   'PublishedAt': '2023-10-04T13:30:12Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/nzJJP-uDIZc/default.jpg',
#   'Duration': 'PT13M47S',
#   'Views_count': '27421',
#   'Likes_count': '859',
#   'Comments_count': '63',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'BNmoCYk58mU',
#   'Vide_name': 'From 16 years of CAREER GAP To becoming a Software Engineer | How to get a JOB after a career gap',
#   'Tags': ['how to get job after career gap',
#    'career gap software jobs',
#    'career gap reason in interview',
#    'career gap of 10 years',
#    'career gap to software engineer',
#    'podcast',
#    'job podcast',
#    'career podcast',
#    'career gap podcast',
#    'career gap interview',
#    'career gap interview questions for freshers',
#    'techtfq',
#    'career advice',
#    'job'],
#   'Description': "How do you get a JOB when having 16 years of CAREER GAP? \nThis is a Podcast video where I talk to Angelina Daisy, who got a job as a Software Engineer after 16 years of career gap.\n\nMany people struggle to get jobs due to career gaps and it's mainly due to a few reasons which we shall discuss during this podcast.\n\nLinkedIn of Angelina Daisy:\nhttps://www.linkedin.com/in/angelina-daisy-602416244/\n\nBootcamp which Angelina took to get the job:\nhttps://hubs.la/Q022Q7G20\n\nTimestamp:\n00:00 Intro\n00:49 Intro about Angelina \n01:59 When and What prompted Angelina to look for a job?\n03:00 What courses did Angelina take?\n04:39 Current job and responsibilities\n05:54 Why OdinSchool Bootcamp & Details\n08:55 The most important thing to get a job\n10:18 Unsuccessful Interviews\n11:55 Details about Successful Interview\n12:51 Question by a recruiter: Why do you have a career gap?\n15:00 Suggestion to get a job after a career gap\n17:13 What do you do in your current job?\n18:11 Is it scary to start a career after a long gap?\n19:24 Would you recommend OdinSchool Bootcamp?\n20:21 Summarizing the whole discussion\n22:55 Final thoughts from Angelina\n\nJOIN my Python Bootcamp:\nhttps://techtfq.graphy.com/courses/Python-Bootcamp-for-Beginners-64d0e0a2e4b067acf3a67a2b-64d0e0a2e4b067acf3a67a2b?buy=true\n\nJOIN my SQL Bootcamp:\nhttps://techtfq.graphy.com/courses/Recordings-from-SQL-Bootcamp-64f0e1cae4b014d5beccb78e\n\n\nTHANK YOU!",
#   'PublishedAt': '2023-09-21T13:00:15Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/BNmoCYk58mU/default.jpg',
# ...
#   'PublishedAt': '2020-12-11T02:10:35Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/Hl4NZB1XR9c/default.jpg',
#   'Duration': 'PT1H10M21S',
#   'Views_count': '1055127',
#   'Likes_count': '22526',
#   'Comments_count': '672',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '1aybOgni7lI',
#   'Vide_name': 'How to install PostgreSQL on Mac OS | Install and Uninstall PostgreSQL Database',
#   'Tags': ['PostgreSQL',
#    'pgAdmin',
#    'Database',
#    'PostgreSQL Database',
#    'Install PostgreSQL',
#    'Uninstall PostgreSQL',
#    'Install pgAdmin',
#    'Uninstall pgAdmin',
#    'Interactive installer by EDB',
#    'Postgres.app',
#    'EDB',
#    'Setup PostgreSQL',
#    'macOS Big Sur',
#    'Mac OS',
#    'macOS',
#    'how to install postgresql',
#    'postgres',
#    'postgresql tutorial',
#    'pgadmin 4',
#    'pgadmin4',
#    'how to install',
#    'how to uninstall',
#    'setup',
#    'setup postgresql',
#    'install postgresql on mac',
#    'uninstall postgresql on mac',
#    'install pgadmin on mac'],
#   'Description': "This video is about how to install PostgreSQL database, doing the initial setup of the PostgreSQL\nand then also explains how to uninstall PostgreSQL database on macOS Big Sur.\nThis video also covers how to install pgAdmin and how to uninstall pgAdmin from macOS Big Sur.\n\nIn this video, I cover PostgreSQL installation using the Interactive installer by EDB and also by Postgres.app\nAlso cover the uninstallation of PostgreSQL database using both the Interactive installer by EDB and also by Postgres.app\n\nWe go step by step from scratch to complete installation, setup and uninstallation of PostgreSQL.\nWe also create a sample database and table using pgAdmin and then insert data to this table in pgAdmin.\n\nWe look at the error's caused in Postgres 13.1 version when trying to install through the Interactive installer by EDB method.\n\nThis video covers the following:\n1) Install PostgreSQL using the Interactive installer by EDB method.\n2) Setup pgAdmin which is installed as part of the EDB installer.\n3) Create sample database and table to test pgAdmin.\n4) Uninstall PostgreSQL using the uninstaller package provided by the EDB installer.\n5) Install PostgreSQL using Postgres.app method.\n6) Initialise database and setup command line path for PostgreSQL database.\n7) Install pgAdmin.\n8) Uninstall PostgreSQL database using uninstallation steps provided by Postgres.app\n\n\nMentioned below are the links mentioned in video:\n\nPostgreSQL:\nhttps://www.postgresql.org/\n\npgAdmin:\nhttps://www.pgadmin.org/\n\nLearn What is Database & Different types of Database (for beginners):\nhttps://www.youtube.com/watch?v=j09EQ-xlh88&t=333s\n\n\nI hope the video was useful. Please like, subscribe and comment any queries or issues you may have faced during your PostgreSQL installation.\n\nThank you and stay tuned for more SQL, Database and other tech video's on this channel. \n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq",
#   'PublishedAt': '2020-11-16T02:28:09Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/1aybOgni7lI/default.jpg',
#   'Duration': 'PT20M51S',
#   'Views_count': '106553',
#   'Likes_count': '933',
#   'Comments_count': '117',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'j09EQ-xlh88',
#   'Vide_name': 'Learn What is Database | Types of Database | DBMS',
#   'Tags': ['Database',
#    'DBMS',
#    'Relational Database',
#    'Non-Relational Database',
#    'Non Relational Database',
#    'Data',
#    'Key Value Database',
#    'Key-Value Store',
#    'Document Database',
#    'Document Store',
#    'Graph Database',
#    'Wide Column Database',
#    'Column Family Database',
#    'SQL',
#    'Database Application',
#    'RDBMS',
#    'Flat File Database',
#    'Hierarchical Database',
#    'Network Database',
#    'Learn Database',
#    'Learn DBMS',
#    'Oracle',
#    'MySQL',
#    'Microsoft SQL Server',
#    'PostgreSQL',
#    'MongoDB',
#    'Database for Beginners',
#    'Database Tutorial',
#    'Database Basics'],
#   'Description': 'In this video, we learn everything we need to know about Databases. Relational database and also other types of database like the NoSQL Database or Non Relational database. \n\nData has never been more crucial than it is today. Storing, managing and protecting data is of utmost importance. Due to this, databases have evolved rapidly over the last decade to cater the need of rapidly growing data and to support data in different size, shape and formats.\n\nThe aim of this video is to help everyone to learn what is database and the different types of database available today. This video also answers if DBMS is same as database. We also briefly look at the evolution of database.\n\nIn this video, I also touch upon the basics of relational database and non relational database. We briefly look at different categories of non relation database.\n\nI’ve used animated video’s to make the content more interesting to watch.\n\nListing below the contents of this video for a quick glance on what is covered:\nIntroduction\nWhat is Data?\nWhat is Database?\nIs DBMS same as Database?\nEvolution of Database\nRelational Database\nNon-Relational Database (which covers below categories)\nKey Value Database (Key Value Store)\nDocument Database (Document Store)\nGraph Database\nWide Column Database (Column Family Database)\n\nHope you learn something useful from this video and hopefully it helps you in some way or the other.\n\nPlease comment your thoughts and subscribe to the channel.\n\n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq',
#   'PublishedAt': '2020-08-30T00:38:24Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/j09EQ-xlh88/default.jpg',
#   'Duration': 'PT12M11S',
#   'Views_count': '336718',
#   'Likes_count': '5558',
#   'Comments_count': '151',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '7nzTDrio7vY',
#   'Vide_name': 'Do you need a Smartwatch',
#   'Tags': ['Do you need a smartwatch',
#    'Samsung Galaxy Watch Active 2',
#    'Best smartwatch',
#    'smartwatch vs traditional watch',
#    'what is so special about the smartwatch',
#    'smartwatch',
#    'samsung galaxy watch',
#    'galaxy watch active 2',
#    'top smartwatches',
#    'smart watch'],
#   'Description': "In this video, I talk about the advantageous of having a smartwatch. I also mention which is the best smartwatch you can buy.\nIn this video I am showcasing Samsung Galaxy Watch Active 2 which I believe is the best value for money smartwatch you can buy.\n\nVideo also covers, how a smartwatch can help you get more serious about your health and fitness.\n\nDo you need a smartwatch? \nIf you are not sure then watch this video where I explain why its better to buy a smartwatch over a traditional watch.\nAnd if you decide to buy a smartwatch then in this video I explain why the Samsung Galaxy Watch Active 2 is one of the best smartwatches that you can buy right now, especially if you are an android user. You probably won't find a better smartwatch than Samsung Galaxy Watch Active2. \n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq",
#   'PublishedAt': '2020-07-12T15:32:36Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/7nzTDrio7vY/default.jpg',
#   'Duration': 'PT7M43S',
#   'Views_count': '11585',
#   'Likes_count': '185',
#   'Comments_count': '43',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'J-uCLHTIWZ4',
#   'Vide_name': 'MacBook Pro 13 2020  One Week Later Review',
#   'Tags': None,
#   'Description': "Macbook Pro 13 2020 review after one week. Quick review on my MacBook Pro experience. \nSummarizing my one week experience with 6 things I loved and 3 things I did not.\n\nIf you haven't watched my unboxing video then please find it here:\nhttps://www.youtube.com/watch?v=_BMPh5M4BIY\n\nPlease do comment and let me know if you agree with the Pros and Cons.\n\nThank you! \n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq",
#   'PublishedAt': '2020-06-29T15:03:19Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/J-uCLHTIWZ4/default.jpg',
#   'Duration': 'PT9M24S',
#   'Views_count': '1498',
#   'Likes_count': '73',
#   'Comments_count': '20',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': '_BMPh5M4BIY',
#   'Vide_name': 'MacBook Pro 13 2020 Unboxing',
#   'Tags': ['#MacBookPro13', '#Unboxing', '#Apple', '#Malaysia', 'macbook pro'],
#   'Description': 'This video is about unboxing of New MacBook Pro 13 laptop and its accessories.\nThis is the MacBook Pro 13 of 2020 with i5 intel processor, 1TB SSD hard disc, 16GB of RAM. It\'s the space grey color laptop.\n\nUnboxing my brand new 2020 MacBook Pro 13" laptop. My first experience with apple device. \nAlso unboxing Magic Mouse 2, incase sleeve for 13" MacBook Pro laptop, apple USB C to USB A adapter and Samsonite bag pack.\n\nMacBook Pro 13\nhttps://www.apple.com/my/shop/buy-mac/macbook-pro/13-inch\n\nCheck out the 1 week review of this laptop below:\nhttps://www.youtube.com/watch?v=J-uCLHTIWZ4&t=46s \n\n\n🔴 WATCH MORE VIDEOS HERE 👇\n\n✅ SQL Tutorial - Basic concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HQQ_COgGb7kf_1H8UWUBxO\n\n✅ SQL Tutorial - Intermediate concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FD9XspliRM_HZM_jK7tkii\n\n✅ SQL Tutorial - Advance concepts:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GbmgiW4TWVnxhjMFOIf0Q7\n\n✅ Practice Solving Basic SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9F66P3GFo5O6nJ4DfZNhVsp\n\n✅ Practice Solving Intermediate SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EIYmNXJ8ZtQ1bmLIpt0SpV\n\n✅ Practice Solving Complex SQL Queries:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9Fahr7taauUx5RnTfuGyL--\n\n✅ Data Analytics Career guidance:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FDsr995DjwCy9XNaIukb8P\n\n✅ SQL Course, SQL Training Platform Recommendations:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9GqF1Q_zn8KnYvFgtEOh-2n\n\n✅ Python Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW\n\n✅ Git and GitHub Tutorial:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9EI1MPlqqDpe3bgr8RJZE0b\n\n✅ Data Analytics Projects:\nhttps://www.youtube.com/playlist?list=PLavw5C92dz9HwT_uStsDdJbuBOt_XD0ch\n\nTHANK YOU,\nThoufiq',
#   'PublishedAt': '2020-06-22T14:49:50Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/_BMPh5M4BIY/default.jpg',
#   'Duration': 'PT9M19S',
#   'Views_count': '2875',
#   'Likes_count': '97',
#   'Comments_count': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
def get_comment_details(co_ids):
    comment_data=[]
    try:
        for co_id  in co_ids:
                            c_request=youtube.commentThreads().list(
                                part="snippet",
                                videoId=co_id,
                                maxResults=50
                            )
                            c_response=c_request.execute()

                            for item in c_response['items']:
                                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                                comment_data.append(data)                         
    except:
        pass

    return comment_data

# %%
c_details = get_comment_details(v_id)

# %%
c_details
# Out:
# [{'Comment_Id': 'UgwvZLeZaSgKOx3miU54AaABAg',
#   'Comment_Text': 'this problem was really interesting, thank you.. i solved it❤',
#   'Comment_Author': '@ehsanshakeri620',
#   'Comment_Published': '2024-03-15T21:03:16Z'},
#  {'Comment_Id': 'UgwW2mkZt76JThm2bnx4AaABAg',
#   'Comment_Text': 'God of SQL ❤',
#   'Comment_Author': '@Ed-TalkWithArpit',
#   'Comment_Published': '2024-03-15T17:36:13Z'},
#  {'Comment_Id': 'UgzkPAw-YEDi6Q0ZO2l4AaABAg',
#   'Comment_Text': 'Hi , how yo contact you. I want to take help in person ❤',
#   'Comment_Author': '@shovabaral2797',
#   'Comment_Published': '2024-03-15T16:49:16Z'},
#  {'Comment_Id': 'UgxmolV4D1QfBdlL6cR4AaABAg',
#   'Comment_Text': 'SELECT FRIEND1, FRIEND2, (CASE WHEN REGEXP_COUNT(FRLIST, &#39;[^,]+&#39;) = 3 THEN 2 WHEN REGEXP_COUNT(FRLIST, &#39;[^,]+&#39;) = 2 THEN 1 ELSE 0 END) AS MUTUAL_FRIENDS FROM (<br>SELECT * FROM FRIENDS F LEFT JOIN (<br>SELECT FR1, LISTAGG(FRLIST,&#39;,&#39;) WITHIN GROUP (ORDER BY FR1) AS FRLIST FROM (<br>SELECT FRIEND1 AS FR1, LISTAGG(FRIEND2,&#39;,&#39;) WITHIN GROUP (ORDER BY FRIEND1) AS FRLIST<br>FROM FRIENDS<br>GROUP BY FRIEND1<br>UNION ALL<br>SELECT FRIEND2 AS FR1, LISTAGG(FRIEND1,&#39;,&#39;) WITHIN GROUP (ORDER BY FRIEND2) AS FRLIST<br>FROM FRIENDS<br>GROUP BY FRIEND2)<br>GROUP BY FR1) D<br>ON F.FRIEND1 = D.FR1);',
#   'Comment_Author': '@sammail96',
#   'Comment_Published': '2024-03-15T16:33:08Z'},
#  {'Comment_Id': 'UgwKVDHtzyWKo-miWD94AaABAg',
#   'Comment_Text': 'Great solution as always! I have a question regarding query efficiency: in the above code you used a correlated subquery which might be problematic when the data is scaled to much larger sizes since correlated subqueries are iterative (the in operator you used will go through the entire dataset for each outer query) compared to standard set based SQL operations like self join. <br>So will it not be better to solve the entire problem only using self joins rather than using correlated subqueries? I tried using only self joins and the code looked much larger than yours as I had to use multiple ctes. But sometimes length of the code doesn&#39;t translate to higher optimization. <br><br>What are your comments on using self join vs correlated subquery?<br><br>my solution without using the correlated subquery (only self joins):<br>\r<br>with cte as\r<br>(select *, row_number() over() as rn from table),\r<br>cte_left as\r<br>(\r<br>select t1.friend1 as f1, t1.friend2 as f2, t2.friend1 as f3, t2.friend2 as f4, t1.rn as r1, t2.rn as r2\r<br>from cte as t1 join cte as t2\r<br>on (t1.friend1=t2.friend1 or t1.friend1=t2.friend2) \r<br>and (t1.rn&lt;&gt;t2.rn) order by t1.friend1),\r<br>cte_right as\r<br>(\r<br>select t1.friend1 as f1, t1.friend2 as f2, t2.friend1 as f3, t2.friend2 as f4, t1.rn as r1, t2.rn as r2\r<br>from cte as t1 join cte as t2\r<br>on (t1.friend2=t2.friend1 or t1.friend2=t2.friend2) \r<br>and (t1.rn&lt;&gt;t2.rn) order by t1.friend1),\r<br>cte_final as \r<br>(\r<br>select c1.f1,c1.f2,c1.f3,c1.f4,c2.f3 as f5,c2.f4 as f6, c1.r1 as new_rn \r<br>from cte_left as c1 join cte_right as c2 on c1.r1=c2.r1 \r<br>where (c1.f3=c2.f3 or c1.f3=c2.f4  or c1.f4=c2.f3 or c1.f4=c2.f4) order by new_rn)\r<br>select friend1,friend2,count(f1) as mutual_friends \r<br>from cte left join cte_final on cte.rn=cte_final.new_rn\r<br>group by friend1, friend2;',
#   'Comment_Author': '@Tusharchitrakar',
#   'Comment_Published': '2024-03-15T15:15:15Z'},
#  {'Comment_Id': 'Ugw38AGbyHZ_WpVpN6p4AaABAg',
#   'Comment_Text': 'Great explanation',
#   'Comment_Author': '@rajkumarrajan8059',
#   'Comment_Published': '2024-03-15T14:30:08Z'},
#  {'Comment_Id': 'UgyMGJ8zNyq8T8FXTxN4AaABAg',
#   'Comment_Text': 'Please adjust ur mic<br>Sound is too low',
#   'Comment_Author': '@Junnediya',
#   'Comment_Published': '2024-03-15T14:19:05Z'},
#  {'Comment_Id': 'Ugyodp1n0txtylxU6cx4AaABAg',
#   'Comment_Text': 'I guess by the end of  30 queries, anyone who is able to understand the 30 query concepts, I guess he can eaily be certified with SQL, It literally covers all topics, how to think logically which concept your weak at and so, we gotta really appreciate this guy for his hardwork and effort, maybe in few days this is will be recorded best yotube channel to learn sql across all nations, Keep Going Sir, Wish you start Python too and Data Science Topics.',
#   'Comment_Author': '@sandeepa8755',
#   'Comment_Published': '2024-03-15T13:42:50Z'},
#  {'Comment_Id': 'UgzpkVZzod2Cz0LTIHZ4AaABAg',
#   'Comment_Text': 'Waiting for your upload daily😅',
#   'Comment_Author': '@sushmithasuresh8807',
#   'Comment_Published': '2024-03-15T13:27:02Z'},
#  {'Comment_Id': 'UgyYUWcIvGRO7hIiwlZ4AaABAg',
#   'Comment_Text': '👍',
#   'Comment_Author': '@Anishcko13',
#   'Comment_Published': '2024-03-15T13:15:11Z'},
#  {'Comment_Id': 'UgwcZTlRLUoa9gj_g3p4AaABAg',
#   'Comment_Text': 'After so many failures , got my first solution<br>with cte(serial_no,invoice_date,missed_range,tmp) as<br>    (<br>select serial_no,invoice_date,<br>    case<br>    when <br>    lead(serial_no,1,serial_no+1) over(order by serial_no) - serial_no = 1 then 1<br>    else lead(serial_no,1,0) over(order by serial_no) - serial_no<br>    end<br>    as missed_range , 1 as tmp<br>    from invoice<br>    union all<br>    select serial_no + 1,invoice_date,missed_range,tmp +1<br>    from cte<br>    where tmp &lt; missed_range<br>    )<br>select serial_no,invoice_date from cte<br>order by serial_no<br>Thank you for the series',
#   'Comment_Author': '@sureshraina321',
#   'Comment_Published': '2024-03-16T03:52:11Z'},
#  {'Comment_Id': 'UgzhrKZEatficOBzS7R4AaABAg',
#   'Comment_Text': 'In SQL Server, SELECT generate_series (1,5)  comes up as a built in function and even the text of generate_series  is PINK like any typical function... but I get this error.  Msg 195, Level 15, State 10, Line 10\r<br>&#39;generate_series&#39; is not a recognized built-in function name.   Anyone have any idea?  Maybe it&#39;s not available in SQL Server Express which is my version.',
#   'Comment_Author': '@malcorub',
#   'Comment_Published': '2024-03-15T23:40:57Z'},
#  {'Comment_Id': 'Ugwbx8T3R31rKRhGwmN4AaABAg',
#   'Comment_Text': 'Thanks for such a great challenge series. I look forward to it everyday. Hoping to do a big catch up over the weekend. My Solution:                                                                                                             ; WITH Min_cte AS\r<br>(\r<br>SELECT \r<br>\tMIN(serial_no) AS Min_Invoice,\r<br>\tMAX(serial_no) AS Max_Invoice\r<br>FROM\r<br>\tinvoice\r<br>),\r<br>Recursive_cte AS\r<br>(\r<br>SELECT\r<br>\tMin_Invoice\r<br>FROM\r<br>\tMin_cte\r<br>UNION ALL\r<br>SELECT\r<br>\tr.Min_Invoice + 1\r<br>FROM\r<br>\tRecursive_cte AS r\r<br>\tINNER JOIN Min_cte AS m\r<br>\tON r.Min_Invoice &lt; m.Max_Invoice\r<br>)\r<br>SELECT\r<br>\tR.Min_Invoice \r<br>FROM\r<br>\tRecursive_cte AS r\r<br>\tLEFT JOIN invoice AS i\r<br>\tON r.Min_Invoice = i.serial_no\r<br>WHERE\r<br>\ti.serial_no IS NULL                                                                                                                                  Loving it! Can we get an extension on the 30 days?',
#   'Comment_Author': '@TheCraigie007',
#   'Comment_Published': '2024-03-15T23:11:48Z'},
#  {'Comment_Id': 'UgxbuZOEFGfu4Egclvd4AaABAg',
#   'Comment_Text': 'SQL SERVER SOLUTION: <br><br>DECLARE @min_serial_no INT<br>SELECT  @min_serial_no = MIN(serial_no) from invoice<br><br>DECLARE @max_serial_no INT<br>SELECT  @max_serial_no = MAX(serial_no) from invoice<br><br>CREATE TABLE <a href="http://www.youtube.com/results?search_query=%23mytemp">#MYTEMP</a><br>(<br>serial_no INT<br>)<br><br>WHILE (@min_serial_no &lt;= @max_serial_no)<br>BEGIN<br>\tINSERT INTO <a href="http://www.youtube.com/results?search_query=%23mytemp">#MYTEMP</a> SELECT @min_serial_no<br>\tSET @min_serial_no = @min_serial_no+1<br>END<br><br>SELECT serial_no FROM <a href="http://www.youtube.com/results?search_query=%23mytemp">#MYTEMP</a><br>EXCEPT<br>SELECT serial_no FROM invoice',
#   'Comment_Author': '@blse2000',
#   'Comment_Published': '2024-03-15T15:10:17Z'},
#  {'Comment_Id': 'UgxhEuCJlcx1VMf2Qrl4AaABAg',
#   'Comment_Text': 'Please adjust ur mic. Sound is low',
#   'Comment_Author': '@Junnediya',
#   'Comment_Published': '2024-03-15T14:13:54Z'},
#  {'Comment_Id': 'Ugxforj6LPxiwA1KxWx4AaABAg',
#   'Comment_Text': 'using mysql easiest solution<br><br>with recursive cte as (<br>          select min(serial_no) as series from invoice<br>          union all<br>          select series+1 as series from cte where series&lt;(select max(serial_no) from invoice)<br><br>)<br>select series as MISSING_SERIAL_NO<br>from cte<br>left join invoice i on i.serial_no=cte.series<br>where serial_no is null',
#   'Comment_Author': '@Satish_____Sharma',
#   'Comment_Published': '2024-03-15T07:29:34Z'},
#  {'Comment_Id': 'UgwM756ptIXqSuOo0ZZ4AaABAg',
#   'Comment_Text': 'Hi , I&#39;m using ORACLE SQL facing below error after executing recursive query:<br>ORA-32039: recursive WITH clause must have column alias list\r<br>32039. 00000 -  &quot;recursive WITH clause must have column alias list&quot;\r<br>*Cause:    A WITH clause query referred to itself (recursive) but did\r<br>           not have a column alias list specified for it.\r<br>*Action:   Add a column alias list for the WITH clause query name.',
#   'Comment_Author': '@kartikwagh6971',
#   'Comment_Published': '2024-03-15T06:58:25Z'},
#  {'Comment_Id': 'UgyixggyFBQ6-UnlPCF4AaABAg',
#   'Comment_Text': 'thank you for this series.',
#   'Comment_Author': '@rohitkulkarni2241',
#   'Comment_Published': '2024-03-15T06:30:56Z'},
#  {'Comment_Id': 'UgzjrN0Tn6Ezw4-vKPh4AaABAg',
#   'Comment_Text': 'Thank you <br>You are amazing, thank you for the generosity!!',
#   'Comment_Author': '@rajkumarrajan8059',
#   'Comment_Published': '2024-03-15T05:56:35Z'},
#  {'Comment_Id': 'UgxctK_NScTisBujJTR4AaABAg',
#   'Comment_Text': '🔥🔥',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2024-03-15T04:01:42Z'},
#  {'Comment_Id': 'UgyuGQGNQL3q_kpurBp4AaABAg',
#   'Comment_Text': 'SQl Server solution...<br><br>with cte as<br>(<br>\tselect\tmin(serial_no) as rn_min<br>\t\t\t, max(serial_no) as rn_max<br>\tfrom invoice<br>)<br>, cte2 as<br>(<br>\tselect serial_no <br>\tfrom invoice cross join cte <br>\twhere serial_no = rn_min<br><br>\tunion all<br><br>\tselect serial_no + 1<br>\tfrom cte2 cross join cte <br>\twhere serial_no &lt; rn_max<br>)<br>select a.serial_no as missing_serial_no <br>from cte2 a<br>left join invoice b on a.serial_no = b.serial_no<br>where b.serial_no is null',
#   'Comment_Author': '@sanjeetsignh',
#   'Comment_Published': '2024-03-15T04:00:52Z'},
#  {'Comment_Id': 'UgyfBlM5Ynaz7QRQLHl4AaABAg',
#   'Comment_Text': 'I am not able to put where condition to stop recursion in sql server<br>.<br>error showing &quot;GROUP BY, HAVING, or aggregate functions are not allowed in the recursive part of a recursive common table expression &#39;cte&#39;.&quot;<br>Also Generate series works different in sql server.<br>can&#39;t find a solution. Pls help',
#   'Comment_Author': '@user-mq3st9cl9j',
#   'Comment_Published': '2024-03-15T03:39:29Z'},
#  {'Comment_Id': 'UgyQfJ7-syuLgrL6aM54AaABAg',
#   'Comment_Text': 'here is my solution:<br><br><br>with MinMax as (<br><br>\t\tselect  MIN(serial_no) as min_num,<br>\t\t\t\tMAX(serial_no) as max_num<br>\t\tfrom invoice<br>)<br>, cte as (<br>\t\tselect min_num as number <br>\t\tfrom MinMax<br>\t\tunion all<br>\t\tselect number + 1 as number<br>\t\tfrom cte<br>\t\twhere number &lt; (select max_num from MinMax)<br>\t\t<br>\t\t)<br>\t\tselect distinct number as MISSING_SERIAL_NO<br>\t\tfrom cte<br>\t\tleft join invoice on cte.number = invoice.serial_no<br>\t\twhere serial_no is null<br><br>thanks for the challenges',
#   'Comment_Author': '@montudeb8060',
#   'Comment_Published': '2024-03-15T03:36:14Z'},
#  {'Comment_Id': 'UgwNxmUsyCz9-Gb5Trx4AaABAg',
#   'Comment_Text': 'Thank you for this series..',
#   'Comment_Author': '@user-mq3st9cl9j',
#   'Comment_Published': '2024-03-15T03:21:54Z'},
#  {'Comment_Id': 'Ugx2xPyG-SkKetkhUvZ4AaABAg',
#   'Comment_Text': 'Excellent job keep it continuously we  will be grateful',
#   'Comment_Author': '@ajaysaroha2539',
#   'Comment_Published': '2024-03-15T03:21:40Z'},
#  {'Comment_Id': 'Ugzfq-gyuGcJrltRElR4AaABAg',
#   'Comment_Text': 'for ms sql i found following solution<br><br>DECLARE @start as int\r<br>DECLARE @stop as int;\r<br>DECLARE @step as int = 1;<br><br>select @start = min(serial_no), @stop= MAX(serial_NO)<br>from invoice<br> <br>select  value from GENERATE_SERIES(@Start,@stop,@step) <br>except <br>select serial_no from invoice<br>order by 1;',
#   'Comment_Author': '@f2lusapon83',
#   'Comment_Published': '2024-03-14T23:56:48Z'},
#  {'Comment_Id': 'UgzQX6OQxYS_A1cI6iR4AaABAg',
#   'Comment_Text': 'Learning new ones 👍🙏',
#   'Comment_Author': '@bashad4133',
#   'Comment_Published': '2024-03-14T22:57:23Z'},
#  {'Comment_Id': 'UgzOlL2Ly2VzZgwAVGl4AaABAg',
#   'Comment_Text': 'Keep it going... And thanks for the wonderful content you are putting out everyday',
#   'Comment_Author': '@ybalasaireddy1248',
#   'Comment_Published': '2024-03-14T21:02:23Z'},
#  {'Comment_Id': 'UgyWKVHhCJ-cERidWqZ4AaABAg',
#   'Comment_Text': 'For SSMS<br><br>WITH NumberSeries AS (\r<br>    SELECT 330115 AS SerialNumber\r<br>    UNION ALL\r<br>    SELECT SerialNumber + 1\r<br>    FROM NumberSeries\r<br>    WHERE SerialNumber &lt; 330125\r<br>)\r<br>SELECT SerialNumber\r<br>FROM NumberSeries\r<br>except\r<br>SELECT serial_no\r<br>FROM invoice',
#   'Comment_Author': '@Leo-qo5hk',
#   'Comment_Published': '2024-03-14T19:55:29Z'},
#  {'Comment_Id': 'Ugwtw9hoeakIBkA9xhl4AaABAg',
#   'Comment_Text': 'thank you, waiting for tomorrow🙏',
#   'Comment_Author': '@ehsanshakeri620',
#   'Comment_Published': '2024-03-14T19:37:17Z'},
#  {'Comment_Id': 'Ugy0nLQi-tPeZ0-_yxZ4AaABAg',
#   'Comment_Text': '❤',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2024-03-14T18:09:00Z'},
#  {'Comment_Id': 'UgxjvQkynCO5Z8amr494AaABAg',
#   'Comment_Text': 'Awesome',
#   'Comment_Author': '@rajkumarrajan8059',
#   'Comment_Published': '2024-03-14T07:29:42Z'},
#  {'Comment_Id': 'Ugy5sgud_MOTSgELEmx4AaABAg',
#   'Comment_Text': 'select name, cnt from(<br>\tselect manager, count(*) as cnt from employee_managers where manager is not null group by manager<br>)t1 left join employee_managers t2 on t1.manager = id order by cnt desc;',
#   'Comment_Author': '@SelvamB-es9ew',
#   'Comment_Published': '2024-03-14T06:07:51Z'},
#  {'Comment_Id': 'UgyXL4njAFqVOJ6FiC14AaABAg',
#   'Comment_Text': 'Toufiq, can you please take one problem from materialized view ?',
#   'Comment_Author': '@akashchristopher',
#   'Comment_Published': '2024-03-14T05:52:51Z'},
#  {'Comment_Id': 'UgyPFaNScS-mcAEnAk54AaABAg',
#   'Comment_Text': 'Can you please teach us M query language',
#   'Comment_Author': '@minakemkar9070',
#   'Comment_Published': '2024-03-14T02:51:43Z'},
#  {'Comment_Id': 'UgznIoZCMvj4eyhDVF54AaABAg',
#   'Comment_Text': 'Hi toufiq, can solve problems regarding FIFO in SQL<br>How we apply FIFO for calculating Holding &amp; PNL while buying stock',
#   'Comment_Author': '@dmrockers1266',
#   'Comment_Published': '2024-03-13T18:14:56Z'},
#  {'Comment_Id': 'Ugw4ImrUIM7N1-kMtcN4AaABAg',
#   'Comment_Text': 'Hey toufiq, are you giving the problems in increasing difficulties? Because today is the first day I found you video and I&#39;d like to follow it from today rather than rushing from day 1. i want to do them later when I finish with you.',
#   'Comment_Author': '@junaidmahmud2894',
#   'Comment_Published': '2024-03-13T18:11:12Z'},
#  {'Comment_Id': 'UgwqIEoupiLkIV9aL9F4AaABAg',
#   'Comment_Text': 'if we use group by <a href="http://man.name/">man.name</a> and if there are two or more person with same name? instead we can use group by <a href="http://man.id/">man.id</a>',
#   'Comment_Author': '@jjayeshpawar',
#   'Comment_Published': '2024-03-13T17:33:26Z'},
#  {'Comment_Id': 'Ugx9KvTq_dw5nV-oGHZ4AaABAg',
#   'Comment_Text': 'select distinct <a href="http://e2.name/">e2.name</a>,count(1) as no_of_employees <br>from employee_managers e1<br>join employee_managers e2<br>\ton e1.manager=<a href="http://e2.id/">e2.id</a><br>group by <a href="http://e2.name/">e2.name</a><br>order by no_of_employees desc;',
#   'Comment_Author': '@deadkiller6050',
#   'Comment_Published': '2024-03-13T17:28:24Z'},
#  {'Comment_Id': 'UgwdNVjCbTJZ-MwQ0D54AaABAg',
#   'Comment_Text': 'It will be handled by self join',
#   'Comment_Author': '@sunilparker5690',
#   'Comment_Published': '2024-03-13T15:15:33Z'},
#  {'Comment_Id': 'UgyWbOGSukOiy3sGvYR4AaABAg',
#   'Comment_Text': 'Hi i am a great admirer of your work ......i think  there is no point in giving toughest challenge for challenge sake .....anyone watch these videos for either interview sake or to use in their work ....i wish plz try to cover all kind of queries that would be useful for interview and work , in that process plz try to include all sql concepts , built in functions ......so that kind of revision of all sql concepts ......this is just my wish',
#   'Comment_Author': '@krishnasangati',
#   'Comment_Published': '2024-03-13T14:53:15Z'},
#  {'Comment_Id': 'Ugw5Txqa1DDHsSRBs8V4AaABAg',
#   'Comment_Text': 'Hi toufiq, by the end of this series can you give atleast 1 extremely almost unsolvable problem which you might have encountered in a real world scenario? So far the questions are very good but the difficulty level of all 13 problems were not very high.',
#   'Comment_Author': '@Tusharchitrakar',
#   'Comment_Published': '2024-03-13T13:39:17Z'},
#  {'Comment_Id': 'UgwNkxNmWSVKUWL3Cvl4AaABAg',
#   'Comment_Text': '❤',
#   'Comment_Author': '@pragatiaggarwal8103',
#   'Comment_Published': '2024-03-13T13:35:15Z'},
#  {'Comment_Id': 'Ugx4nb9nQuXLoRjPT2N4AaABAg',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@Ksureshkumar01',
#   'Comment_Published': '2024-03-13T13:20:45Z'},
#  {'Comment_Id': 'UgyQNS2kf5s1QK1Zhot4AaABAg',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@MinhazTaher',
#   'Comment_Published': '2024-03-13T13:17:21Z'},
#  {'Comment_Id': 'UgxlGdmw5IOPVpLuV9B4AaABAg',
#   'Comment_Text': 'Toughest and most confusing one so far.',
#   'Comment_Author': '@charanteja6808',
#   'Comment_Published': '2024-03-15T21:16:58Z'},
#  {'Comment_Id': 'UgxjmYUPRQqJntiE_Zl4AaABAg',
#   'Comment_Text': 'Sir the above solution works only when we add new teams in the table, if there is another hierarchy it will not give results. I write  solution of above query it might works for that problem too team(please correct me sir if I&#39;m wrong) <br>MS Sql<br><br> <br>--new hierarchy<br>insert into company values (&#39;david&#39;,null);<br>insert into company values (&#39;bill&#39;,&#39;david&#39;);<br><br>select * from company;<br>with root as(<br>select employee from company<br>where manager is null)<br>, <br>teams as(<br>select concat(&#39;team &#39;,row_number() over ( partition by root.employee order by (select null)),&#39; of_&#39;,root.employee) team<br>, c.employee, root.employee as manager<br><br>from company c<br>inner join <br>root<br>on <br>root.employee=c.manager)  <br><br>,rec  as(<br>select team,employee,manager from teams<br><br>union all<br>select <a href="http://rec.team/">rec.team</a>, c.employee, c.manager<br><br>from rec<br>inner join company c<br>on<br>rec.employee=c.manager<br><br><br>)<br>select team, string_agg(employee, &#39;,&#39;) members<br>from<br>(select team, employee from rec<br>union <br>select team,manager from rec) k <br>group by team<br>Order by team;',
#   'Comment_Author': '@atifsuhail7803',
#   'Comment_Published': '2024-03-14T08:57:04Z'},
#  {'Comment_Id': 'UgyRXSrgThh1CmGOfgl4AaABAg',
#   'Comment_Text': 'You have made with great logic, I revised 2 times to get the logic... but this problem is very challenging',
#   'Comment_Author': '@Rameshkumar-dk8me',
#   'Comment_Published': '2024-03-13T18:40:54Z'},
#  {'Comment_Id': 'UgyvfFrmnwApPaBkg3d4AaABAg',
#   'Comment_Text': 'Hi,  your source code brings following error, do you check the source  code before you offer this to the public?<br><br>sg 102, Level 15, State 1, Procedure spChallange#12, Line 25 [Batch Start Line 7]\r<br>Incorrect syntax near &#39;cte&#39;.\r<br>Msg 102, Level 15, State 1, Procedure spChallange#12, Line 39 [Batch Start Line 7]\r<br>Incorrect syntax near &#39;,&#39;.',
#   'Comment_Author': '@f2lusapon83',
#   'Comment_Published': '2024-03-13T12:19:33Z'},
#  {'Comment_Id': 'UgyMR4BQAqhEWptu61x4AaABAg',
#   'Comment_Text': 'This is scary for me',
#   'Comment_Author': '@sam02109',
#   'Comment_Published': '2024-03-13T09:32:43Z'},
#  {'Comment_Id': 'UgwjoOuBoKBGhimct7l4AaABAg',
#   'Comment_Text': 'ms sql approach<br><br><br>with a as (<br>select c2.employee, c2.manager, 1 hier, ROW_NUMBER() over(order by c2.employee) team<br>from company c1 join company c2 on c2.manager=c1.employee<br>where c1.manager is null <br>union all<br>select company.employee, company.manager, hier+1 hier, <a href="http://a.team/">a.team</a><br>from a join company on a.employee=company.manager<br>), <br><br>b as (<br>select employee, team, ROW_NUMBER() over(partition by team order by hier) rn<br>from (<br>select manager employee, team, 0 hier<br>from a<br>where hier = 1<br>union all<br>select employee, team, hier<br>from a<br>) t )<br><br>select concat(&#39;team&#39;,team) team, string_agg(employee, &#39;,&#39;) WITHIN GROUP (ORDER BY rn) members<br>from b<br>group by team',
#   'Comment_Author': '@Alexpudow',
#   'Comment_Published': '2024-03-13T08:55:22Z'},
#  {'Comment_Id': 'Ugy2IQfhhK1TZCGl5eV4AaABAg',
#   'Comment_Text': 'Can you please provide sql server solution',
#   'Comment_Author': '@SujathaAhilan-bj4qe',
#   'Comment_Published': '2024-03-13T05:30:13Z'},
#  {'Comment_Id': 'UgzwpUA2PJqjSzc5knN4AaABAg',
#   'Comment_Text': 'Thank you so much sir',
#   'Comment_Author': '@user-mq3st9cl9j',
#   'Comment_Published': '2024-03-13T03:12:37Z'},
#  {'Comment_Id': 'UgzGksu9Rh5f0X0mT8d4AaABAg',
#   'Comment_Text': 'I think u used a lengthy and confusing approch- my soln would be -            with recursive cte as (<br>select employee ,manager, row_number() over () as x from company where manager = (select employee from company where manager is null)<br>union all <br>select d.employee, d.manager, x from cte c join company d on c.employee = d.manager )<br><br>select concat(&#39;team&#39;,x) as teams,  group_concat(manager separator &#39;,&#39;) as members from (select manager , x from cte union select employee,x from cte<br><br>)y group by x order  by x;',
#   'Comment_Author': '@vikramjitsingh6769',
#   'Comment_Published': '2024-03-12T23:18:43Z'},
#  {'Comment_Id': 'UgwheECUwv_4HcBylsx4AaABAg',
#   'Comment_Text': 'This one was over my head,  I need to work on my recursive cte understanding.    At any rate I always learn from your videos even when i don&#39;t fully understand the final solution.',
#   'Comment_Author': '@malcorub',
#   'Comment_Published': '2024-03-12T18:36:48Z'},
#  {'Comment_Id': 'UgyHswX7UUuLFV7AOjt4AaABAg',
#   'Comment_Text': 'my solution on MySql:<br><br>with recursive cte as(<br>select b.employee, b.employee as x,a.employee as y from(<br>select employee from company where manager is null ) a <br>join company b on a.employee=b.manager<br>union all<br>select<br>cte.employee, c.employee, y<br>from cte join company c on cte.x=c.manager<br>)<br><br>select concat(&quot;Team&quot;,row_number() over()) as TEAMS, <br>concat(group_concat(distinct y),&quot;,&quot;,group_concat(x)) as MEMBERS from cte<br>group by employee',
#   'Comment_Author': '@gabrielcarbajalcarbajal3025',
#   'Comment_Published': '2024-03-12T17:20:16Z'},
#  {'Comment_Id': 'UgxoitR6CwB5u-8VIut4AaABAg',
#   'Comment_Text': 'I modified this query to sql server ,<br> but error message says Msg 462, Level 16, State 1, Line 1\r<br>Outer join is not allowed in the recursive part of a recursive common table expression &#39;cte&#39;. How to resolve this?',
#   'Comment_Author': '@kanappilly',
#   'Comment_Published': '2024-03-12T17:09:46Z'},
#  {'Comment_Id': 'UgyglNQ_vcmSP9YXW6R4AaABAg',
#   'Comment_Text': 'As always best 😊',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2024-03-12T16:59:08Z'},
#  {'Comment_Id': 'UgxP2UoLV6EQxu6BIMR4AaABAg',
#   'Comment_Text': 'plz provide class 12 th dataset, the shared dataset is  of  previous class',
#   'Comment_Author': '@naveendevihosur8050',
#   'Comment_Published': '2024-03-12T16:36:30Z'},
#  {'Comment_Id': 'UgyayRru2kWmKoj5r0d4AaABAg',
#   'Comment_Text': '🤯🤯',
#   'Comment_Author': '@harishbagran6052',
#   'Comment_Published': '2024-03-12T16:00:43Z'},
#  {'Comment_Id': 'UgxW8qMKKEce0ipYjSh4AaABAg',
#   'Comment_Text': 'Shared dataset is older, please provide for this query',
#   'Comment_Author': '@jjayeshpawar',
#   'Comment_Published': '2024-03-12T15:40:30Z'},
#  {'Comment_Id': 'UgxKZlU78r6ZeJEqa0R4AaABAg',
#   'Comment_Text': 'Thank you so much learnt new things ❤',
#   'Comment_Author': '@splendidabhi',
#   'Comment_Published': '2024-03-12T14:43:54Z'},
#  {'Comment_Id': 'UgxV8NC9iGcaoD_2Dit4AaABAg',
#   'Comment_Text': 'Bro , can you please explain in oracle',
#   'Comment_Author': '@ongole_boy6346',
#   'Comment_Published': '2024-03-12T11:35:47Z'},
#  {'Comment_Id': 'Ugw3hR6Kj9Y3hWUHo8F4AaABAg',
#   'Comment_Text': 'Thank You Sir!',
#   'Comment_Author': '@sat9sh',
#   'Comment_Published': '2024-03-12T01:34:39Z'},
#  {'Comment_Id': 'UgyJfw5a2jlwncFSu-N4AaABAg',
#   'Comment_Text': 'thank you,',
#   'Comment_Author': '@hassamulhaq7762',
#   'Comment_Published': '2024-03-12T01:06:00Z'},
#  {'Comment_Id': 'UgxdZUXBwHcMEroYVA94AaABAg',
#   'Comment_Text': 'sir, please put a video on  different star pattern forming with mysql .',
#   'Comment_Author': '@user-cf9zf3ig4c',
#   'Comment_Published': '2024-03-12T01:05:13Z'},
#  {'Comment_Id': 'Ugwwk_pfocHeLsJ5ext4AaABAg',
#   'Comment_Text': 'Not a full proof solution as one partition might have more than one distinct outliers..Not sure how rank function will help there',
#   'Comment_Author': '@arnabsarkar6159',
#   'Comment_Published': '2024-03-11T20:46:24Z'},
#  {'Comment_Id': 'UgyMAUCXBQ6HkrAz2SZ4AaABAg',
#   'Comment_Text': 'Thank you so much',
#   'Comment_Author': '@user-mq3st9cl9j',
#   'Comment_Published': '2024-03-11T19:58:22Z'},
#  {'Comment_Id': 'UgwwGOzRdEXR4sEaEb94AaABAg',
#   'Comment_Text': 'with cte as (\r<br>select *, first_value(rating) over(partition by hotel order by avg desc) as odd from (\r<br>select *,abs(rating-avg(rating) over(partition by hotel)) as avg from hotel_ratings)\r<br>order by hotel, avg desc)\r<br>\r<br>select hotel_ratings.hotel,hotel_ratings.year,hotel_ratings.rating from hotel_ratings\r<br>left join cte\r<br>on hotel_ratings.rating = cte.odd \r<br>where cte.rating is null\r<br>order by hotel_ratings.hotel desc,hotel_ratings.year',
#   'Comment_Author': '@jjayeshpawar',
#   'Comment_Published': '2024-03-11T17:30:24Z'},
#  {'Comment_Id': 'UgyVuxXxqEu3rsSY1WN4AaABAg',
#   'Comment_Text': '@TFQ     Generalized solution that will work for many outliers<br><br>WITH cte AS (\r<br>    SELECT hotel,year,rating, CAST(AVG(rating) OVER(PARTITION BY hotel ORDER BY hotel) AS DECIMAL(9,1)) AS avg_rating, STDEV(rating) over(partition by hotel order by hotel) as std_dev \r<br>    FROM  hotel_ratings\r<br>),\r<br>cte1 AS (\r<br>    SELECT  * ,ABS(rating - avg_rating) AS diff_rating , cast(avg_rating + std_dev as decimal(9,1)) as positive , cast(avg_rating - std_dev as decimal(9,1)) as negative from cte\r<br>\t\r<br>),cte2\r<br>as\r<br>(\r<br>Select *, CASE WHEN rating &lt;= positive and rating &gt;=negative THEN 1 else 0 end as flag from cte1\r<br>)\r<br>select hotel,year,rating from cte2 \r<br>where flag &lt;&gt; 0\r<br>order by hotel desc, year asc',
#   'Comment_Author': '@navaneeth6414',
#   'Comment_Published': '2024-03-11T17:26:27Z'},
#  {'Comment_Id': 'UgzFXLUAKvjkHUs9VLt4AaABAg',
#   'Comment_Text': 'My solution:<br><br>Correct me if am wrong<br><br>WITH cte AS (\r<br>    SELECT hotel,year,rating, CAST(AVG(rating) OVER(PARTITION BY hotel ORDER BY hotel) AS DECIMAL(9,1)) AS avg_rating \r<br>    FROM  hotel_ratings\r<br>),\r<br>cte1 AS (\r<br>    SELECT  * ,ABS(rating - avg_rating) AS flag1 from cte\r<br>\t\r<br>),cte2 as\r<br>(\r<br>select *,max(flag1) over(partition by hotel order by hotel) as maxFlag from cte1\r<br>)\r<br>(select Hotel,year,rating from  cte2 \r<br>where flag1 &lt;&gt; maxFlag)\r<br>ORDER BY hotel DESC',
#   'Comment_Author': '@navaneeth6414',
#   'Comment_Published': '2024-03-11T16:56:08Z'},
#  {'Comment_Id': 'UgwSt90FPKEZb28icnp4AaABAg',
#   'Comment_Text': 'Sorry to say but your approach to this problem is naive and as a data analyst/scientist you need to make sure your solution is statistically accurate. I&#39;ll tell you a major flaw with your solution with an example:<br>If you have multiple outliers in each hotel your solution will not identify those outliers since you are only identifying 1 extreme outlier with the maximum deviation from the mean but this does not mean that other outliers cannot exist. <br><br>Right solution:<br>Apart from mean also calculate the standard deviation for each hotel (every rdbms has a function for that else can be done manually too). In statistics there is something called the 3 Sigma rule (if an assumption can be made that the data distribution is approximately gaussian and this is also called the Z score technique) which needs to be applied here. Essentially, the outliers will be those records whose values are mean (mu) +/- 3* standard deviation (Sigma). This logic has to be applied to obtain the outliers. <br>If your goal is to just apply SQL logic with window functions it is okay but since you are talking about a business case scenario it is important to be statistically accurate <br>That being said thank you for your continuous efforts in helping us build strong SQL foundations.',
#   'Comment_Author': '@Tusharchitrakar',
#   'Comment_Published': '2024-03-11T13:55:57Z'},
#  {'Comment_Id': 'UgxE5FfPDrwGhgFcYTZ4AaABAg',
#   'Comment_Text': 'Instead of ranking, is there any other logic to find outlier step at the last as step?',
#   'Comment_Author': '@digitaltechconnect1318',
#   'Comment_Published': '2024-03-11T13:50:38Z'},
#  {'Comment_Id': 'UgzOIitubOQs6K1-LjR4AaABAg',
#   'Comment_Text': 'This is another approach for solving the problem<br>with cte as(\r<br>select  sum(case when indicator = &#39;velocity&#39; then value end) velocity,\r<br>max(case when indicator = &#39;level&#39; then value end) levels, repair_date,client,auto from auto_repair\r<br>group by repair_date,client,auto)\r<br>select velocity,\r<br>case when sum(case when levels =&#39;good&#39; then 1 else 0 end) good,\r<br>sum(case when levels = &#39;wrong&#39; then 1 else 0 end) wrong,\r<br>sum(case  when levels = &#39;regular&#39; then 1 else 0 end) regular\r<br> from cte group by velocity order by velocity;',
#   'Comment_Author': '@user-fc2ed1fy9n',
#   'Comment_Published': '2024-03-15T06:01:02Z'},
#  {'Comment_Id': 'Ugw3Qzifgk-ScLoi0lh4AaABAg',
#   'Comment_Text': 'My solution -MSSQL<br>with cte as(<br>select indicator,value,lag(value) over(partition by client, auto, repair_date<br>order by (select null)<br>) val from auto_repair)<br>select value, <br>sum(iif(val= &#39;good&#39;,1,0)) good, <br>sum(iif(val = &#39;wrong&#39;, 1,0)) wrong , <br>sum(iif(val = &#39;regular&#39;,1, 0)) regular<br>from cte<br>where val is not null<br>group by value;',
#   'Comment_Author': '@atifsuhail7803',
#   'Comment_Published': '2024-03-12T12:26:35Z'},
#  {'Comment_Id': 'UgyJmx-6sVLZGFaHsHR4AaABAg',
#   'Comment_Text': 'Nice problem thanks for giving some tricky 😊questions to slove',
#   'Comment_Author': '@AnilKumar-qe6er',
#   'Comment_Published': '2024-03-11T14:31:48Z'},
#  {'Comment_Id': 'Ugxe-5qyAx_SC27wVqB4AaABAg',
#   'Comment_Text': 'Here it&#39;s my approach in MSSQL...<br><br>WITH \r<br>LEVEL AS (SELECT * FROM AUTO_REPAIR WHERE INDICATOR=&#39;LEVEL&#39;),\r<br>VELOCITY AS (SELECT * FROM AUTO_REPAIR WHERE INDICATOR=&#39;VELOCITY&#39;),\r<br>JOINS AS(SELECT L.*,V.VALUE AS VELOCITY_VALUE FROM LEVEL L JOIN VELOCITY V\r<br>\t\tON L.CLIENT=V.CLIENT\r<br>\t\tAND L.AUTO=<a href="http://v.auto/">V.AUTO\r</a><br>\t\tAND L.REPAIR_DATE=V.REPAIR_DATE),\r<br>CATEGORY AS (\r<br>\t\tSELECT *,\r<br>\t\tCASE WHEN VALUE=&#39;GOOD&#39; THEN 1 ELSE 0 END AS GOOD,\r<br>\t\tCASE WHEN VALUE=&#39;REGULAR&#39; THEN 1 ELSE 0 END AS REGULAR,\r<br>\t\tCASE WHEN VALUE=&#39;WRONG&#39; THEN 1 ELSE 0 END AS WRONG\r<br>\t\tFROM [JOINS])\r<br>\r<br>SELECT VELOCITY_VALUE,sum(GOOD),sum(REGULAR),sum(WRONG) FROM CATEGORY\r<br>GROUP BY VELOCITY_VALUE',
#   'Comment_Author': '@user-ff1fg4yb6r',
#   'Comment_Published': '2024-03-11T14:29:20Z'},
#  {'Comment_Id': 'UgyeOJwlTYYTSmZvlNJ4AaABAg',
#   'Comment_Text': 'select velocity<br>,count(case level when &#39;good&#39; then 1 end) good<br>,count(case level when &#39;wrong&#39; then 1 end) wrong<br>,count(case level when &#39;regular&#39; then 1 end) regular<br>from (<br>select a.value velocity, b.value level<br>from auto_repair a<br>join<br>(select * from auto_repair<br>where indicator like &#39;level&#39;) b<br>on a.client=b.client and a.auto=<a href="http://b.auto/">b.auto</a> and a.repair_date = b.repair_date<br>where a.indicator like &#39;velocity&#39;) t<br>group by velocity',
#   'Comment_Author': '@Alexpudow',
#   'Comment_Published': '2024-03-11T11:56:53Z'},
#  {'Comment_Id': 'UgwuKpk6n9Re_a89uw14AaABAg',
#   'Comment_Text': 'Here is my approach using mysql<br><br>with cte as (SELECT client, auto, repair_date, indicator, value,row_number() over () as rn FROM auto_repair )<br>,cte1 as (select client, auto, repair_date, indicator, value, rn,lag(value) over (order by rn) as cnt  from cte )<br><br>select value as Velocity,sum(case when cnt=&#39;good&#39; then 1 else 0 end) as good,<br>\t\t\t sum(case when cnt=&#39;wrong&#39; then 1 else 0 end) as wrong,<br>\t\t\t sum(case when cnt=&#39;regular&#39; then 1 else 0 end) as regular<br>             <br>from cte1 where indicator=&#39;velocity&#39; group by value order by  Velocity',
#   'Comment_Author': '@Satish_____Sharma',
#   'Comment_Published': '2024-03-11T07:36:21Z'},
#  {'Comment_Id': 'Ugz0OaykFQQwcYZVKlN4AaABAg',
#   'Comment_Text': 'MySQL Solution -<br><br>with cte as (<br>select v.value velocity, l.value level, count(v.value) as cnt<br>from auto_repair v<br>join auto_repair l<br>on v.client = l.client and v.repair_date = l.repair_date and <a href="http://v.auto/">v.auto</a> = <a href="http://l.auto/">l.auto</a><br>where v.indicator = &#39;velocity&#39; and l.indicator = &#39;level&#39;<br>group by v.value,l.value<br>)<br>select velocity,<br>sum(case when level = &#39;good&#39; then cnt else 0 end ) as good,<br>sum(case when level = &#39;wrong&#39; then cnt else 0 end) as wrong,<br>sum(case when level = &#39;regular&#39; then cnt else 0 end ) as regular<br>from cte<br>group by velocity <br>order by velocity',
#   'Comment_Author': '@sapnasaini851',
#   'Comment_Published': '2024-03-11T06:50:52Z'},
#  {'Comment_Id': 'Ugy_HPYDcKRrZr4mxsR4AaABAg',
#   'Comment_Text': 'Thank You so much',
#   'Comment_Author': '@user-mq3st9cl9j',
#   'Comment_Published': '2024-03-11T06:47:08Z'},
#  {'Comment_Id': 'UgwuIE1MB_LymIzXLyV4AaABAg',
#   'Comment_Text': 'Thanks a lot , Sir',
#   'Comment_Author': '@RABBANIBAJISHAIK',
#   'Comment_Published': '2024-03-11T01:33:56Z'},
#  {'Comment_Id': 'Ugy8MJBLAIvd_Ngl5al4AaABAg',
#   'Comment_Text': 'Hi, in your download file is it a little bit different from  your video presentaion, in the your file  is the field &quot;Count&quot; listet, and this makes a wrong result. Can u check it please. The results  a different as your online presentation.  Ty. 😇<br><br>-- Solution using PIVOT in Micrososft SQLServer<br>select *<br>from <br>    (<br>        select v.value velocity, l.value level,count(1) as count😇<br>        from auto_repair l<br>        join auto_repair v on v.auto=<a href="http://l.auto/">l.auto</a> and v.repair_date=l.repair_date and l.client=v.client<br>        where l.indicator=&#39;level&#39;<br>        and v.indicator=&#39;velocity&#39;<br>        group by v.value,l.value<br>    ) bq<br>pivot <br>    (<br>        count(level)<br>        for level in ([good],[wrong],[regular])<br>    ) pq;<br><br><br>velocity\tcount\tgood\twrong\tregular\r<br>50\t1\t0\t1\t0\r<br>70\t1\t0\t1\t0\r<br>80\t1\t1\t0\t1\r<br>90\t2\t1\t0\t0',
#   'Comment_Author': '@f2lusapon83',
#   'Comment_Published': '2024-03-11T01:21:49Z'},
#  {'Comment_Id': 'UgzBJ2ptyHv4oxoa7ch4AaABAg',
#   'Comment_Text': 'Wow thank You!',
#   'Comment_Author': '@juanromantorres5063',
#   'Comment_Published': '2024-03-10T21:23:45Z'},
#  {'Comment_Id': 'UgzYS54aIeeWFxOLeHR4AaABAg',
#   'Comment_Text': 'Hi sir, than you for all the hardwork you put in! This is an amazing series. :)) Below is my approach for this problem : <br><br>with mycte as<br>(<br>select new_velocity,<br>case when new_velocity = x.value then (lag(x.value,1) over(partition by client, repair_date order by repair_date)) end as new_val<br>from<br>(<br>select *,<br>case when indicator = &#39;velocity&#39; then value else NULL end as new_velocity<br>from auto_repair<br>)as x<br>) <br><br>select new_velocity as velocity, <br>sum(case when new_val = &#39;good&#39; then 1 else 0 end) as good,<br>sum(case when new_val = &#39;wrong&#39; then 1 else 0 end) as wrong,<br>sum(case when new_val = &#39;regular&#39; then 1 else 0 end) as regular<br>from mycte <br>where new_velocity is not null and new_val is not null<br>group by new_velocity',
#   'Comment_Author': '@saralavasudevan5167',
#   'Comment_Published': '2024-03-10T21:19:59Z'},
#  {'Comment_Id': 'UgwuUt1QdlUJbIut_8R4AaABAg',
#   'Comment_Text': 'Thank you sir, I want to learn this kind of complex query from you. If you are providing any training then I am eager to join sir',
#   'Comment_Author': '@alokkumarsahu3035',
#   'Comment_Published': '2024-03-10T19:00:18Z'},
#  {'Comment_Id': 'UgxLj5UTOktzYsIoM5t4AaABAg',
#   'Comment_Text': 'Thanks',
#   'Comment_Author': '@ashutoshpratapsingh6872',
#   'Comment_Published': '2024-03-10T17:03:06Z'},
#  {'Comment_Id': 'UgxIoNdVNQuZMpCqUmd4AaABAg',
#   'Comment_Text': 'Many thanks Thoufiq! Using MSSQL.',
#   'Comment_Author': '@rojas556',
#   'Comment_Published': '2024-03-10T15:58:53Z'},
#  {'Comment_Id': 'UgxxLvlyQLfvbGdrBxd4AaABAg',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2024-03-10T15:53:27Z'},
#  {'Comment_Id': 'UgyWNfgx-fjlUzopAt14AaABAg',
#   'Comment_Text': 'My approach to solve this (Mysql)                                                                                                                                                                                     with cte as  (<br>select m.value as velocity, n.value as level<br>from <br>(select *<br>from auto_repair<br>where indicator =&quot;level&quot;) n<br>inner join <br>(select *<br>from auto_repair<br>where indicator =&quot;velocity&quot;) m<br>on n.client = m.client and <a href="http://n.auto/">n.auto</a> =<a href="http://m.auto/">m.auto</a> and n.repair_date = m.repair_date)<br><br>select velocity,<br>        sum(if(level = &quot;good&quot;,1,0))as &quot;good&quot;,<br>        sum(if(level= &quot;wrong&quot;,1,0)) as &quot;wrong&quot;,<br>        sum(if(level= &quot;regular&quot;,1,0)) as &quot;wrong&quot;<br> from cte<br> group by velocity<br> order by velocity;',
#   'Comment_Author': '@ishanshubham8355',
#   'Comment_Published': '2024-03-10T15:16:46Z'},
#  {'Comment_Id': 'UgzZ8Vz6T6wUsZetm_R4AaABAg',
#   'Comment_Text': 'with cte as (<br>\t\t\tselect value,<br>\t\t\trow_number() over() as count<br>\t\t\tfrom auto_repair<br>\t\t\twhere indicator = &#39;velocity&#39;),<br>\tcte1 as (select value,<br>\t\t\trow_number() over() as count<br>\t\t\tfrom auto_repair<br>\t\t\twhere indicator = &#39;level&#39;)<br>select c.value as velocity,<br>count(case when  c1.value  = &#39;good&#39; then c.value  end) as &#39;good&#39;,<br>count(case when  c1.value  = &#39;wrong&#39; then c.value  end) as &#39;wrong&#39;,<br>count(case when  c1.value  = &#39;regular&#39; then c.value  end) as &#39;regular&#39;<br>from cte c<br>join cte1 c1 on c.count = c1.count<br>group by c.value<br>order by c.value',
#   'Comment_Author': '@rohithbhanuprakash4682',
#   'Comment_Published': '2024-03-10T15:10:03Z'},
#  {'Comment_Id': 'UgzulY4jfTd_wpH3mDV4AaABAg',
#   'Comment_Text': 'we  can avoid doing the join with the help of window function as this can improve the performance, my approach is below<br><br>-----mysql approach<br>with cte as (<br>\tselect *, lag(value) over(order by client) as &#39;level&#39; from auto_repair<br>),<br>cte_final as (<br>\tselect value as velocity, sum(case when level = &#39;good&#39; then 1 else 0 end) as good,<br>\t\t\t\t\tsum(case when level = &#39;wrong&#39; then 1 else 0 end) as wrong,<br>                    sum(case when level = &#39;regular&#39; then 1 else 0 end) as regular<br>\t\t\tfrom cte where indicator=&#39;velocity&#39; group by 1 order by 1<br>)<br>select * from cte_final;',
#   'Comment_Author': '@arnavkashyap822',
#   'Comment_Published': '2024-03-10T14:47:56Z'},
#  {'Comment_Id': 'UgyHwq5hKvDNpOlB5Id4AaABAg',
#   'Comment_Text': 'create table b as <br>(with a as <br>(select customer_id ,dates, group_concat(product_id) as product_id<br> from orders group by customer_id , dates)<br><br>select dates, product_id from a) ;<br><br>select dates, product_id from orders <br>union all <br>select dates, product_id from b order by dates,product_id;',
#   'Comment_Author': '@NabeelKhan-um1zk',
#   'Comment_Published': '2024-03-16T05:25:17Z'},
#  {'Comment_Id': 'UgxaFpeRm3E8y4YCT894AaABAg',
#   'Comment_Text': 'select dates,concat_ws(&#39;,&#39;,product_id,lag_id) as product_id \r<br>from (\r<br>select  customer_id,dates,product_id,lag(product_id)over(partition by customer_id,dates)as lag_id from public.customer_product \r<br>)a order by dates',
#   'Comment_Author': '@ShirleyShi-zb5us',
#   'Comment_Published': '2024-03-14T02:26:34Z'},
#  {'Comment_Id': 'Ugxxc5LvAcC6J344XVt4AaABAg',
#   'Comment_Text': 'with cte as<br>(select * , <br>\trow_number() over(partition by customer_id,dates) as rn,lag(product_id,1)over() as lf<br>\tfrom orders),<br>    cte1 as<br>\t(select dates,concat(product_id,&#39; &#39;,lf) as product_<br>\tfrom cte<br>\twhere rn = 2)<br>select dates,product_id from orders union<br>select * from cte1 <br>order by dates',
#   'Comment_Author': '@nileshpandey8247',
#   'Comment_Published': '2024-03-13T20:01:51Z'},
#  {'Comment_Id': 'UgwxpNQAX0HxmTcrTFd4AaABAg',
#   'Comment_Text': 'My solution: SELECT dates,product_id::STRING AS product_id FROM &quot;ORDERS&quot;\r<br>union\r<br>SELECT DISTINCT dates,list_prod AS product_id FROM \r<br>(select *,listagg(product_id,&#39;,&#39;) WITHIN GROUP (ORDER BY product_id ) OVER (PARTITION BY dates,customer_id) AS list_prod\r<br>from orders)  ORDER BY dates,product_id;',
#   'Comment_Author': '@nadimatlanagesh1951',
#   'Comment_Published': '2024-03-12T14:46:57Z'},
#  {'Comment_Id': 'UgzPxS9xHKYxp_9nBaV4AaABAg',
#   'Comment_Text': 'select dates, product_id<br>from orders<br>union<br>select dates, group_concat(product_id) as products<br>from orders<br>group by dates, customer_id<br>order by dates, product_id',
#   'Comment_Author': '@martinberger365',
#   'Comment_Published': '2024-03-11T13:04:18Z'},
#  {'Comment_Id': 'UgxvCPEC_pfiQe8QK6B4AaABAg',
#   'Comment_Text': 'Without string_Agg, but it has hardcode and depends on each product count per day<br><br>select distinct dates, cast(product_id as varchar) products<br>from orders<br>union<br>select a.dates, concat(a.product_id,&#39;,&#39;,b.product_id) products<br>from (select *, ROW_NUMBER() over(partition by dates, customer_id order by product_id) rn<br>from orders<br>) a <br>join<br>(select * from (<br>select *, ROW_NUMBER() over(partition by dates, customer_id order by product_id) rn<br>from orders) t<br>where rn =2) b <br>on a.customer_id = b.customer_id and a.dates=b.dates<br>where a.rn =1',
#   'Comment_Author': '@Alexpudow',
#   'Comment_Published': '2024-03-10T10:17:43Z'},
#  {'Comment_Id': 'UgwCnAFgj3MK9iNIekN4AaABAg',
#   'Comment_Text': '🔥🔥🔥',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2024-03-10T09:35:22Z'},
#  {'Comment_Id': 'UgyDmcFSE7rtUVCAgKl4AaABAg',
#   'Comment_Text': 'very well explained thank you',
#   'Comment_Author': '@firdosesyed8981',
#   'Comment_Published': '2024-03-10T04:28:29Z'},
#  {'Comment_Id': 'UgyKO2fy7ZvP3kzOfX94AaABAg',
#   'Comment_Text': 'Thank you for your outstanding presentations.  Please make lectures on the Temporal Databases.',
#   'Comment_Author': '@ollehbudiak7150',
#   'Comment_Published': '2024-03-09T22:57:45Z'},
#  {'Comment_Id': 'UgwC2dSCpKzyRW6m5xV4AaABAg',
#   'Comment_Text': 'Super, such a great 30 day  initiative. I am into  it  alot and everyday i am eagerly waiting for your videos  for new challenge 🎉🎉',
#   'Comment_Author': '@babag5324',
#   'Comment_Published': '2024-03-09T18:45:02Z'},
#  {'Comment_Id': 'UgyOZUNM9HtvDariMeh4AaABAg',
#   'Comment_Text': 'I am refining my SQL solving skill for interviews with this series of  videos <a href="http://www.youtube.com/results?search_query=%2330daysqlquerychallenge">#30DaySQLQueryChallenge</a>!',
#   'Comment_Author': '@splendidabhi',
#   'Comment_Published': '2024-03-09T17:00:58Z'},
#  {'Comment_Id': 'UgxqTo8CNcMNTXulw454AaABAg',
#   'Comment_Text': 'Where we use in realtime?',
#   'Comment_Author': '@12ravindrareddy',
#   'Comment_Published': '2024-03-09T16:35:18Z'},
#  {'Comment_Id': 'Ugy4PHVA1ZQsYJBjAsV4AaABAg',
#   'Comment_Text': 'hey tried this in my sql its a bit easy than in postgre sql using group_concat<br>select dates,product_id as products<br>from orders <br>union<br>select dates,group_concat(product_id) as products<br>from orders group by customer_id,dates <br>order by dates,products;',
#   'Comment_Author': '@pradeepvadlakonda007',
#   'Comment_Published': '2024-03-09T16:28:26Z'},
#  {'Comment_Id': 'UgzQ7FrKlikYtwYW53x4AaABAg',
#   'Comment_Text': 'My solution for MS SQL<br><br>with cte as (<br>select customer_id, dates, string_agg(product_id, &#39;,&#39;) within group (order by dates) as products<br>from orders<br>group by customer_id, dates)<br><br>select dates, products from cte<br>union<br>select dates, cast(product_id as nvarchar(max)) from orders',
#   'Comment_Author': '@sunilnair846',
#   'Comment_Published': '2024-03-09T16:27:35Z'},
#  {'Comment_Id': 'UgzwdPJqEhb9fsJpbmd4AaABAg',
#   'Comment_Text': 'Oracle SQL Solution:<br><br>SELECT dates, TO_CHAR(product_id) AS products<br>FROM orders<br><br>UNION<br><br>SELECT dates, LISTAGG(TO_CHAR(product_id), &#39;,&#39;) AS products<br>FROM orders<br>GROUP BY customer_id, dates<br>ORDER BY dates, products;',
#   'Comment_Author': '@vishwanath-ts',
#   'Comment_Published': '2024-03-09T15:41:30Z'},
#  {'Comment_Id': 'UgxajysI3EeFyzP8_d94AaABAg',
#   'Comment_Text': 'Do leetcode - Hard level questions.',
#   'Comment_Author': '@dharmharley6871',
#   'Comment_Published': '2024-03-09T15:24:22Z'},
#  {'Comment_Id': 'UgyGdXiMZPTLi6V0Z-B4AaABAg',
#   'Comment_Text': 'mysql user here. Its group_concat there as a replacement for the string_agg function in PostgreSQL',
#   'Comment_Author': '@dakshbhatnagar',
#   'Comment_Published': '2024-03-09T14:30:31Z'},
#  {'Comment_Id': 'UgzC2PchCtYL6p7JV7B4AaABAg',
#   'Comment_Text': 'select dates,product_id::text\r<br>from orders_techtfq\r<br>union \r<br>select dates,string_agg(product_id::text,&#39;,&#39;) from orders_techtfq\r<br>group by customer_id,dates\r<br>order by dates,product_id',
#   'Comment_Author': '@Kirankumar-ml1ro',
#   'Comment_Published': '2024-03-09T14:25:09Z'},
#  {'Comment_Id': 'UgxTPWDgK61jkLQHwq94AaABAg',
#   'Comment_Text': '(select * from orders)<br>union<br>(select customer_id,dates,group_concat(product_id) as product_id<br>from orders<br>group by customer_id,dates)<br>order by dates,customer_id,product_id',
#   'Comment_Author': '@kushmanthreddy4762',
#   'Comment_Published': '2024-03-09T14:22:42Z'},
#  {'Comment_Id': 'UgyEVPsxm2KKGRnX2ZV4AaABAg',
#   'Comment_Text': 'I was thinking about the group_concat function. thank you for the series.',
#   'Comment_Author': '@hassamulhaq7762',
#   'Comment_Published': '2024-03-09T14:19:40Z'},
#  {'Comment_Id': 'UgwSP95YqHJkMaF6JEV4AaABAg',
#   'Comment_Text': 'Thank You so much!.',
#   'Comment_Author': '@sunetala2957',
#   'Comment_Published': '2024-03-09T14:11:09Z'},
#  {'Comment_Id': 'UgyCYPx6A0_HMMq2xWR4AaABAg',
# ...
#   'Comment_Text': 'Yes thoufiq bhai,  you are really amazing and sharing the real time based for free,  thank you for your contribution its really worth it,  keep hustling , we are with you ❤❤❤❤',
#   'Comment_Author': '@saladahmednur5189',
#   'Comment_Published': '2023-08-20T04:46:40Z'},
#  {'Comment_Id': 'UgzaO0-ZRV1BaSdyqat4AaABAg',
#   'Comment_Text': 'Thank you so much',
#   'Comment_Author': '@pimpale4052',
#   'Comment_Published': '2023-08-20T01:59:19Z'},
#  {'Comment_Id': 'UgzMiXmXV0Vvy_SJCl94AaABAg',
#   'Comment_Text': 'Hey Thoufiq ,the Platform where you hosted SQL boot camp is shut down,now where can I find the recordings?',
#   'Comment_Author': '@sumanthsaadam4522',
#   'Comment_Published': '2023-08-19T16:18:52Z'},
#  {'Comment_Id': 'UgykERQXAPP7FxX2ANh4AaABAg',
#   'Comment_Text': 'Hi Taufeeq<br>Can&#39;t we use case statement in order to transform row into column for first problem???',
#   'Comment_Author': '@nehalahmad5678',
#   'Comment_Published': '2023-08-19T16:03:21Z'},
#  {'Comment_Id': 'Ugx8kJA_lCrTU9119_x4AaABAg',
#   'Comment_Text': 'It was great, could you please make this type of video in different different scenarios',
#   'Comment_Author': '@muktarulhossain5425',
#   'Comment_Published': '2023-08-19T15:17:13Z'},
#  {'Comment_Id': 'UgxVMVUnNnEVka93HNV4AaABAg',
#   'Comment_Text': 'Sir, i need to learn sql .....let me know when will u start new batch ?',
#   'Comment_Author': '@nivisworld1513',
#   'Comment_Published': '2023-08-19T13:58:20Z'},
#  {'Comment_Id': 'UgzBqfCaB4AL4Z6IIUB4AaABAg',
#   'Comment_Text': 'Sir link',
#   'Comment_Author': '@amleshkumar4868',
#   'Comment_Published': '2023-08-19T13:54:03Z'},
#  {'Comment_Id': 'Ugyu7LKP-ioNN4jB3e54AaABAg',
#   'Comment_Text': 'Big big big fan of your video&#39;s<br>I have one question how to remove deadlocks in MySQL 5.6 or above.. I am using sps and application backend is node js',
#   'Comment_Author': '@RakeshBitling',
#   'Comment_Published': '2023-08-19T13:15:54Z'},
#  {'Comment_Id': 'Ugz22gayJyogoVXhcUl4AaABAg',
#   'Comment_Text': 'Error--- Execution failed on sql &#39;\r<br>        SELECT\r<br>            name\r<br>        FROM\r<br>            sqlite_master\r<br>        WHERE\r<br>            type IN (&#39;table&#39;, &#39;view&#39;)\r<br>            AND name=?;\r<br>        &#39;: not all arguments converted during string formatting<br><br>Anyone, got this error and how to solve it?',
#   'Comment_Author': '@charmiedaftari3285',
#   'Comment_Published': '2024-03-11T22:56:39Z'},
#  {'Comment_Id': 'UgzvnTdkTiTITHFI5t94AaABAg',
#   'Comment_Text': 'I did it the simpler way: downloaded a sample from brightdata as a csv, loaded into jupyter notebook as a pandas dataframe, and translated the title values with deeptranslator python library. Then added that as a column, saved the file, loaded into snowflake',
#   'Comment_Author': '@koosa6289',
#   'Comment_Published': '2024-02-29T11:06:39Z'},
#  {'Comment_Id': 'UgxgbCr6HkiFxFPCcfR4AaABAg',
#   'Comment_Text': 'hi sir. for me it&#39;s not running in virtual environment',
#   'Comment_Author': '@DevyanjaliSrivastava-xz1tz',
#   'Comment_Published': '2024-01-31T20:53:18Z'},
#  {'Comment_Id': 'UgykRU8V5W-xvU9HqoB4AaABAg',
#   'Comment_Text': 'Got best knowledge  from this video ,Thank you so much sir.',
#   'Comment_Author': '@user-el8cf8mt4s',
#   'Comment_Published': '2023-12-25T13:11:48Z'},
#  {'Comment_Id': 'UgwtrVW889IAuaFJavF4AaABAg',
#   'Comment_Text': 'can u pls give the directory  working in windows for the folder gspread',
#   'Comment_Author': '@srivathsanp6252',
#   'Comment_Published': '2023-11-25T14:36:31Z'},
#  {'Comment_Id': 'UgzGhZ2yqAZiolgMde14AaABAg',
#   'Comment_Text': 'much helpful. could u please make a video explaining the use of locals function in python. wouldn&#39;t the above code have worked fine without locals? unable to understand its use here.',
#   'Comment_Author': '@lovebites4098',
#   'Comment_Published': '2023-11-04T05:46:08Z'},
#  {'Comment_Id': 'UgzAgKd9BNKCUoB2AHN4AaABAg',
#   'Comment_Text': 'when i tried to run the fetch address otodom analysis code it is giving me error-non successful status code 429. Getting the location but not the address, How to resolve it ? <a href="https://www.youtube.com/watch?v=D0-Qy7yk5TQ&amp;t=908">15:08</a>',
#   'Comment_Author': '@user-xo9rl6oh4k',
#   'Comment_Published': '2023-10-08T18:08:28Z'},
#  {'Comment_Id': 'Ugx8oUNpDMB0VBQudPJ4AaABAg',
#   'Comment_Text': 'Please explain the SQL query latitude and longitude . How did you remove it explain it please!',
#   'Comment_Author': '@AbuzarKhan-or2wq',
#   'Comment_Published': '2023-09-09T21:00:22Z'},
#  {'Comment_Id': 'UgyRhP3FSnzLm8X25id4AaABAg',
#   'Comment_Text': 'while running the nominatim.reverse(), I was facing an error &quot;SSL: CERTIFICATE_VERIFY_FAILED&quot;. I googled and came up with a solution for this. <br>I want to know if anyone else faced the same issue. I am still in doubt why this issue was coming at the first place. Below the added snippet I used to resolve the issue -<br><br>import certifi<br>import ssl<br>import geopy.geocoders<br>ctx = ssl.create_default_context(cafile=certifi.where())<br>geopy.geocoders.options.default_ssl_context = ctx',
#   'Comment_Author': '@SandipMondal414',
#   'Comment_Published': '2023-09-07T20:23:37Z'},
#  {'Comment_Id': 'UgxO81h-yrXWYD-2C-d4AaABAg',
#   'Comment_Text': 'Thanks you so much for the  great video ..',
#   'Comment_Author': '@1112electronics',
#   'Comment_Published': '2023-08-31T12:44:36Z'},
#  {'Comment_Id': 'Ugw2qQ66jMS41USZRJR4AaABAg',
#   'Comment_Text': 'Generally in how many days are you expected to complete a project like this and present to the client in the real corporate scenario...??',
#   'Comment_Author': '@vaijayantigulve4883',
#   'Comment_Published': '2023-08-30T10:58:28Z'},
#  {'Comment_Id': 'UgxhI5FTLYFlsZTFzWF4AaABAg',
#   'Comment_Text': 'You are a very amazing teacher bro❤....keep slaying',
#   'Comment_Author': '@nitinsharma4121',
#   'Comment_Published': '2023-08-19T08:54:05Z'},
#  {'Comment_Id': 'UgyV3E-G1G4XVx_MLzd4AaABAg',
#   'Comment_Text': 'Hi Toufiq @techTFQ, amazing video. Thank you for sharing such learning again. Instead of using sqlalchemy and snowflake connector package; we can use snowpark api for python client. Snowpark eases the snowflake connection and loading data for the data processing in python. Thanks again.',
#   'Comment_Author': '@arpitgupta3106',
#   'Comment_Published': '2023-08-19T05:16:35Z'},
#  {'Comment_Id': 'Ugz6D72-4wVFxEOFs3t4AaABAg',
#   'Comment_Text': 'Hi TechTFQ, when were you be uploading the third and last part. Thanks a lot for your help.',
#   'Comment_Author': '@superalvaromoreno',
#   'Comment_Published': '2023-08-18T08:37:43Z'},
#  {'Comment_Id': 'Ugzaagr3CR7WX-7ZSdB4AaABAg',
#   'Comment_Text': 'Please upload 3rd part.',
#   'Comment_Author': '@DilpreetSingh-cs7yz',
#   'Comment_Published': '2023-08-18T07:38:08Z'},
#  {'Comment_Id': 'UgwvLn3NOln6asntNIp4AaABAg',
#   'Comment_Text': 'waiting for part 3 .........💕🥰',
#   'Comment_Author': '@uzeyirktk6732',
#   'Comment_Published': '2023-08-16T03:49:02Z'},
#  {'Comment_Id': 'UgxF1uYeKmWM9xmgdY94AaABAg',
#   'Comment_Text': 'if pssble kindly explain regx_instr',
#   'Comment_Author': '@rajm5349',
#   'Comment_Published': '2023-08-14T18:44:51Z'},
#  {'Comment_Id': 'Ugyc5vaTADXyQuQiAjF4AaABAg',
#   'Comment_Text': 'Some confusion which i have and where i am having error:<br>this line -&gt;<br>ddf[&#39;ADDRESS&#39;] = ddf[&#39;LOCATION&#39;].apply(lambda x: geolocator.reverse(Point(x)))<br>1. What is wrong in this  liine?<br>2. There  are some location present where address is mentioned not latitude and longitude , so how have you ran your file without any error sir if they cannot be converted to geopy Point.',
#   'Comment_Author': '@aamirmohiuddin38',
#   'Comment_Published': '2023-08-14T17:19:46Z'},
#  {'Comment_Id': 'Ugwi4AQVFQWmySilFf94AaABAg',
#   'Comment_Text': 'Hi Thoufiq, when is the 3rd part of this project series is coming? waiting for it.',
#   'Comment_Author': '@anjaligoyal5321',
#   'Comment_Published': '2023-08-14T12:01:52Z'},
#  {'Comment_Id': 'Ugztp9ftK_4Eyljl1m54AaABAg',
#   'Comment_Text': '3rd part of otodom Data Analyst project ??',
#   'Comment_Author': '@ABHISHEK-AVK',
#   'Comment_Published': '2023-08-13T17:02:46Z'},
#  {'Comment_Id': 'UgzcejQlegLxVsKXGVF4AaABAg',
#   'Comment_Text': 'Thank you toufiq, your explanation is amazing with ease... waiting for part-3',
#   'Comment_Author': '@samiahmed_007',
#   'Comment_Published': '2023-08-12T04:43:36Z'},
#  {'Comment_Id': 'UgxmF2GN9Fmo0T2Wfs14AaABAg',
#   'Comment_Text': 'Where to paste the credentials file in Windows? please mention the directory!!',
#   'Comment_Author': '@aamirmohiuddin38',
#   'Comment_Published': '2023-08-11T18:02:19Z'},
#  {'Comment_Id': 'UgwXIo_uKizEeIBJTpB4AaABAg',
#   'Comment_Text': 'Hi, first of all thank you for your effort for creating this kind of projects. I would like to see your explanation on substring and ddf.compute() part and also you are just reading 100 records and transforming but why churnsize is 16k. Kindly explain. Thank you again',
#   'Comment_Author': '@june17you',
#   'Comment_Published': '2023-08-09T16:11:58Z'},
#  {'Comment_Id': 'UgxVl5oHZCRSDsVufEV4AaABAg',
#   'Comment_Text': 'Hi Sir, thats a great work from you. Your explanation is with ease, even though its complex project. Thanks!! waiting for part 3.',
#   'Comment_Author': '@sammandapalli1805',
#   'Comment_Published': '2023-08-09T15:04:23Z'},
#  {'Comment_Id': 'UgwSBKOJhA0pUPHZlfx4AaABAg',
#   'Comment_Text': 'Hi Thoufiq Thank you for the amazing content..  Please make a video on Performance tuning on SQL QUERIES',
#   'Comment_Author': '@gopinathedugundla7098',
#   'Comment_Published': '2023-08-09T11:33:49Z'},
#  {'Comment_Id': 'Ugw75WU-WJdq_sle2NJ4AaABAg',
#   'Comment_Text': 'Hi bro, make video separate video and provide content of script in description below',
#   'Comment_Author': '@rajasekhar582',
#   'Comment_Published': '2023-08-09T01:06:04Z'},
#  {'Comment_Id': 'Ugz6RQKo4Kl7MBquUDV4AaABAg',
#   'Comment_Text': 'Hi Tfq, in an interview I was verbally asked a scenario based question. “There are 15 students data in a table with scores. Out of which 15th student score is null. How to calculate 15th student average score?”.',
#   'Comment_Author': '@shaliniramachandrappa',
#   'Comment_Published': '2023-08-08T23:39:12Z'},
#  {'Comment_Id': 'Ugzv-3kBACD1NqG2an94AaABAg',
#   'Comment_Text': 'Hello, I have done the SQL course in Lighthall, however I am unable to access the material, I know that Lighthall is shutting down soon, please advice where can I access the SQL course material.',
#   'Comment_Author': '@user-il7md8uj4u',
#   'Comment_Published': '2023-08-08T16:41:44Z'},
#  {'Comment_Id': 'Ugxk6Xf6blVcUGdX_nN4AaABAg',
#   'Comment_Text': 'Hi bhiya can you make a video on how to approach a sql questions ❓ I am not able to build or think what will be logic behind the question.',
#   'Comment_Author': '@tusharsharma2282',
#   'Comment_Published': '2023-08-08T14:32:20Z'},
#  {'Comment_Id': 'UgxHeLyLQNsS2cBgczx4AaABAg',
#   'Comment_Text': 'Sir please explain regex-instr in sql',
#   'Comment_Author': '@praneethveeramachaneni6672',
#   'Comment_Published': '2023-08-08T13:51:38Z'},
#  {'Comment_Id': 'UgxRWxzwN96ED76z6h54AaABAg',
#   'Comment_Text': 'Sir,<br>As I&#39;m beginner can I start my caree in sql only? Is it possible.',
#   'Comment_Author': '@shivanjalikalbhor7773',
#   'Comment_Published': '2023-08-08T07:47:51Z'},
#  {'Comment_Id': 'Ugx8heDH54L3q54rWkJ4AaABAg',
#   'Comment_Text': 'Hi, I have a recent interview problem statement which I faced in an interview and unable to solve. Consider a sales table where we have product name, month, year, no of products sold in a month of the year. We have to find those products whose sales are continuously increasing for 3 consecutive months. \r<br>\r<br>note 1: there are no sales in a month for certain products and those records are not provided in a table. Say product A has sales increasing in January and February but no sales in March but sales again increased in April. But we do not have a record in the table where there are no sales for march and hence we cannot consider Product A in our output.<br><br>note 2: the other scenario is having two separate sales and product tables. Sales table contains, product id, month, year and sales. Product table contains product id and product name. Problem statement remains the same but with two separate tables now.',
#   'Comment_Author': '@thrilokmadduru3653',
#   'Comment_Published': '2023-08-07T01:53:17Z'},
#  {'Comment_Id': 'Ugx9O-1nIdFE8066R1N4AaABAg',
#   'Comment_Text': 'Hello techTFQ,<br>is possible to create a store procedure that will update a table and change string field to a date field?<br>in a way that if i pass the column name in the call procedure function all the string date in that column will convert to date<br>thank you .',
#   'Comment_Author': '@ryuhayabusa3540',
#   'Comment_Published': '2023-08-06T16:35:49Z'},
#  {'Comment_Id': 'UgyHWD_FkFnLEYi8u494AaABAg',
#   'Comment_Text': 'Yes, Please make a separate video on python script, like how these connections work and other stuff, a detailed video will help. Thank you.',
#   'Comment_Author': '@aamirmohiuddin38',
#   'Comment_Published': '2023-08-06T16:09:20Z'},
#  {'Comment_Id': 'UgzQzjT-ohuqzrB0kPB4AaABAg',
#   'Comment_Text': 'This is not a beginner level project at all. People hardly knows about anything about the complex queries,codes . This is for corporate people.',
#   'Comment_Author': '@pratikjugantmohapatra18',
#   'Comment_Published': '2023-08-06T15:28:06Z'},
#  {'Comment_Id': 'Ugz-JAxlz1355szBvzJ4AaABAg',
#   'Comment_Text': 'I&#39;ve been waiting for this type of video for such a long time that i can&#39;t even express. Please continue helping us, you&#39;re such a inspiration and mentor for us. God bless you 💫💫',
#   'Comment_Author': '@manishsherawat7442',
#   'Comment_Published': '2023-08-06T13:57:19Z'},
#  {'Comment_Id': 'UgxYm4aJ6ScgLItDyCB4AaABAg',
#   'Comment_Text': 'Thank you❤',
#   'Comment_Author': '@Player18345',
#   'Comment_Published': '2023-08-06T13:48:14Z'},
#  {'Comment_Id': 'Ugw9Q7rtKeDaIaF7PBR4AaABAg',
#   'Comment_Text': 'Thanks man! Really appreciate your work.',
#   'Comment_Author': '@RitikKumar-jk8nx',
#   'Comment_Published': '2023-08-06T13:32:00Z'},
#  {'Comment_Id': 'UgwFZKsnLRW570lYdR94AaABAg',
#   'Comment_Text': 'Such a complex project explained with ease.. Only you can do that🙏☺️',
#   'Comment_Author': '@fathimafarahna2633',
#   'Comment_Published': '2023-08-06T13:16:40Z'},
#  {'Comment_Id': 'Ugwm2AzKOVVEpf3Hqot4AaABAg',
#   'Comment_Text': 'Data export option unavailable in brightdata. Any other way please let us know',
#   'Comment_Author': '@matams790',
#   'Comment_Published': '2024-02-29T10:34:03Z'},
#  {'Comment_Id': 'Ugy98x_5JOEQ6IqWCyp4AaABAg',
#   'Comment_Text': 'I am not able to download data. It is asking for money and subscription. What do i do?',
#   'Comment_Author': '@user-vf1gi3gs6w',
#   'Comment_Published': '2024-01-15T09:18:25Z'},
#  {'Comment_Id': 'UgxqbWO1bQVF6wOmdqZ4AaABAg',
#   'Comment_Text': 'After downloading the SAMPLE DATASET it appears in MY DATASET but it gives me payment options?!',
#   'Comment_Author': '@jonjon-vc4yx',
#   'Comment_Published': '2024-01-11T03:02:40Z'},
#  {'Comment_Id': 'Ugyt-whZ8mkAxLsPwEV4AaABAg',
#   'Comment_Text': 'I have downloaded the Otodom  sample data from the brightdata Marketplace. However, the downloaded data&#39;s are not visible under My dataset dashboard. Could somebody guide me.',
#   'Comment_Author': '@user-qf2ny7rk8s',
#   'Comment_Published': '2024-01-03T17:31:08Z'},
#  {'Comment_Id': 'UgyJL35JQVftvN7xH2x4AaABAg',
#   'Comment_Text': 'I am not able to download the dataset, can you please provide the direct download link of the dataset',
#   'Comment_Author': '@deveshmishra794',
#   'Comment_Published': '2023-12-28T06:39:45Z'},
#  {'Comment_Id': 'UgxQip3lyjTIJBOL8Ql4AaABAg',
#   'Comment_Text': 'Very informative , thanks . could you please share me data actually as of now i don&#39;t have official email address so not able to download dataset. so it&#39;s my humble request please send me the data so that i can practice 🙏',
#   'Comment_Author': '@shwetamishra1497',
#   'Comment_Published': '2023-12-22T05:39:32Z'},
#  ...]

# %%
c_obj=pymongo.MongoClient("mongodb://cindhu10:guvi2024@ac-8q7snle-shard-00-00.bw8cuhe.mongodb.net:27017,ac-8q7snle-shard-00-01.bw8cuhe.mongodb.net:27017,ac-8q7snle-shard-00-02.bw8cuhe.mongodb.net:27017/?ssl=true&replicaSet=atlas-6n6ftf-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")
db=c_obj["Youtube_data"]

# %%
def channel_details(ch_id):
    c_details=get_channel_details(ch_id)
    vi_id=get_video_ids(ch_id)
    v_details=get_video_details(vi_id)
    com_details=get_comment_details(vi_id)

    collect=db["channel_details"]
    collect.insert_one({"channel_documents":c_details,
                      "video_documents":v_details,"comment_documents":com_details})
    
    return "uploaded successfully"

# %%
coll = channel_details("UCnz-ZXXER4jOvuED5trXfEA")
coll
# Out:
# 'upload completed successfully'

# %%
def channel_table():
    db = c_obj["Youtube"]
    collect=db["channel_details"]
    ch_list = [ch_data["channel_information"] for ch_data in collect.find({}, {"_id": 0, "channel_information": 1})]
    df = pd.DataFrame(ch_list)
    mysql_conn = pymysql.connect(
                   host="127.0.0.1",
                   user="cindhu@localhost",
                   password="root@123",
                   database= "Youtube",
                   port = 3306)
    cursor=mysql_conn.cursor()
    create_table_query ="""
                        CREATE TABLE IF NOT EXISTS channels(
                        ChannelName VARCHAR(100),
                        ChannelId   VARCHAR(100),
                        playlist_id  VARCHAR(100),
                        Channel_Description LONGTEXT,
                        viewCount INT,
                        subscriberCount BIGINT,
                        VideoCount INT
                        )
                    """
    cursor.execute(create_table_query)
    mysql_conn.commit()

    for _,row in df.ittrows():
        insert_query = """
            INSERT INTO channels (ChannelName, ChannelId, playlist_Id, Channel_Description, viewCount, subscriberCount, videoCount)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query,(
            row['ChannelName'],
            row['ChannelId'],
            row['playlist_id'],
            row['Channel_Description'],
            row['viewCount'],
            row['subscriberCount'],
            row['videoCount']        
            ))
    mysql_conn.commit()
    cursor.close()
    mysql_conn.close()

# %%
channel_table()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 channel_table()
#
# Cell In[168], line 6, in channel_table()
#       4 ch_list = [ch_data["channel_information"] for ch_data in collect.find({}, {"_id": 0, "channel_information": 1})]
#       5 df = pd.DataFrame(ch_list)
# ----> 6 mysql_conn = pymysql.connect(
#       7                host="127.0.0.1",
#       8                user="cindhu@localhost",
#       9                password="root@123",
#      10                database= "Youtube",
#      11                port = 3306)
#      12 cursor=mysql_conn.cursor()
#      13 create_table_query ="""
#      14                     CREATE TABLE IF NOT EXISTS channels(
#      15                     ChannelName VARCHAR(100),
#    (...)
#      22                     )
#      23                 """
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\connections.py:664, in Connection.connect(self, sock)
#     661 self._next_seq_id = 0
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     679 self.set_character_set(self.charset, self.collation)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\connections.py:968, in Connection._request_authentication(self)
#     963 plugin_name = auth_packet.read_string()
#     964 if (
#     965     self.server_capabilities & CLIENT.PLUGIN_AUTH
#     966     and plugin_name is not None
#     967 ):
# --> 968     auth_packet = self._process_auth(plugin_name, auth_packet)
#     969 else:
#     970     raise err.OperationalError("received unknown auth switch request")
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\connections.py:1062, in Connection._process_auth(self, plugin_name, auth_packet)
#    1056     raise err.OperationalError(
#    1057         CR.CR_AUTH_PLUGIN_CANNOT_LOAD,
#    1058         "Authentication plugin '%s' not configured" % plugin_name,
#    1059     )
#    1061 self.write_packet(data)
# -> 1062 pkt = self._read_packet()
#    1063 pkt.check_error()
#    1064 return pkt
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'cindhu@localhost'@'localhost' (using password: YES)")

# %%
def videos_table():
    mysql_conn = mysql.connector.connect(
                   host="localhost",
                   user='root',
                   password="root",
                   database= "Youtube",
                   port=3306
                   )
    cursor=mysql_conn.cursor()
    create_table_query = """
        CREATE TABLE IF NOT EXISTS videos (
            Video_Id VARCHAR(100),
            Video_Name VARCHAR(255),
            Tags TEXT,
            Description TEXT,
            PublishedAt DATETIME,
            Thumbnail VARCHAR(255),
            Duration TIME,
            Views_count INT,
            Likes_count INT,
            Comments_count INT,
            Favorite_Count INT,
            Definition VARCHAR(50),
            Caption_Status VARCHAR(50)
        )
    """
    cursor.execute(create_table_query)
    mysql_conn.commit()
    v_data = get_video_details()
    for data in v_data:
        insert_query = """
            INSERT INTO videos (Video_Id, Video_Name, Tags, Description, PublishedAt, Thumbnail, 
            Duration, Views_count, Likes_count, Comments_count, Favorite_Count, Definition, Caption_Status)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            data['Video_Id'],
            data['Video_Name'],
            ",".join(data['Tags']) if data['Tags'] else None,
            data['Description'],
            data['PublishedAt'],
            data['Thumbnail'],
            data['Duration'],
            data['Views_count'],
            data['Likes_count'],
            data['Comments_count'],
            data['Favorite_Count'],
            data['Definition'],
            data['Caption_Status']
        ))
    mysql_conn.commit()
    cursor.close()
    mysql_conn.close()

# %%
videos_table()
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 videos_table()
#
# Cell In[160], line 2, in videos_table()
#       1 def videos_table():
# ----> 2     mysql_conn = mysql.connector.connect(
#       3                    host="localhost",
#       4                    user='root',
#       5                    password="root",
#       6                    database= "Youtube",
#       7                    port=3306
#       8                    )
#       9     cursor=mysql_conn.cursor()
#      10     create_table_query = """
#      11         CREATE TABLE IF NOT EXISTS videos (
#      12             Video_Id VARCHAR(100),
#    (...)
#      25         )
#      26     """
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:137, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     134     self._socket.switch_to_ssl(**ssl_options)
#     135     self._ssl_active = True
# --> 137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
#     144 self._auth_switch_request(username, password)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\protocol.py:99, in MySQLProtocol.make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      93     username_bytes = username
#      94 packet = struct.pack('<IIB{filler}{usrlen}sx'.format(
#      95     filler='x' * 23, usrlen=len(username_bytes)),
#      96                      client_flags, max_allowed_packet, charset,
#      97                      username_bytes)
# ---> 99 packet += self._auth_response(client_flags, username, password,
#     100                               database,
#     101                               auth_plugin,
#     102                               auth_data, ssl_enabled)
#     104 packet += self._connect_with_db(client_flags, database)
#     106 if client_flags & ClientFlag.PLUGIN_AUTH:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\protocol.py:58, in MySQLProtocol._auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      55     return b'\x00'
#      57 try:
# ---> 58     auth = get_auth_plugin(auth_plugin)(
#      59         auth_data,
#      60         username=username, password=password, database=database,
#      61         ssl_enabled=ssl_enabled)
#      62     plugin_auth_response = auth.auth_response()
#      63 except (TypeError, errors.InterfaceError) as exc:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\authentication.py:190, in get_auth_plugin(plugin_name)
#     187     if authclass.plugin_name == plugin_name:
#     188         return authclass
# --> 190 raise errors.NotSupportedError(
#     191     "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %%
def comments_table():
    mysql_conn = mysql.connector.connect(
                   host="DESKTOP-SKJ3NUN",
                   user="root@localhost",
                   password="root",
                   database= "Youtube",
                   port = 3306)
    cursor=mysql_conn.cursor()
    create_table_query = """
        CREATE TABLE IF NOT EXISTS comments (
            Comment_Id VARCHAR(100),
            Video_Id VARCHAR(100),
            Comment_Text TEXT,
            Comment_Author VARCHAR(255),
            Comment_Published DATETIME
        )
    """
    cursor.execute(create_table_query)
    mysql_conn.commit()

    c_data = get_comment_details()
    for data in c_data:
        insert_query = """
            INSERT INTO comments (Comment_Id, Video_Id, Comment_Text, Comment_Author, Comment_Published)
            VALUES (%s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            data['Comment_Id'],
            data['Video_Id'],
            data['Comment_Text'],
            data['Comment_Author'],
            data['Comment_Published']
        ))
    mysql_conn.commit()
    
    cursor.close()
    mysql_conn.close()

# %%
comments_table()
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 comments_table()
#
# Cell In[154], line 2, in comments_table()
#       1 def comments_table():
# ----> 2     mysql_conn = mysql.connector.connect(
#       3                    host="DESKTOP-SKJ3NUN",
#       4                    user="root",
#       5                    password="root",
#       6                    database= "Youtube",
#       7                    port = 3306)
#       8     cursor=mysql_conn.cursor()
#       9     create_table_query = """
#      10         CREATE TABLE IF NOT EXISTS comments (
#      11             Comment_Id VARCHAR(100),
#    (...)
#      16         )
#      17     """
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection.py:137, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     134     self._socket.switch_to_ssl(**ssl_options)
#     135     self._ssl_active = True
# --> 137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
#     144 self._auth_switch_request(username, password)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\protocol.py:99, in MySQLProtocol.make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      93     username_bytes = username
#      94 packet = struct.pack('<IIB{filler}{usrlen}sx'.format(
#      95     filler='x' * 23, usrlen=len(username_bytes)),
#      96                      client_flags, max_allowed_packet, charset,
#      97                      username_bytes)
# ---> 99 packet += self._auth_response(client_flags, username, password,
#     100                               database,
#     101                               auth_plugin,
#     102                               auth_data, ssl_enabled)
#     104 packet += self._connect_with_db(client_flags, database)
#     106 if client_flags & ClientFlag.PLUGIN_AUTH:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\protocol.py:58, in MySQLProtocol._auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      55     return b'\x00'
#      57 try:
# ---> 58     auth = get_auth_plugin(auth_plugin)(
#      59         auth_data,
#      60         username=username, password=password, database=database,
#      61         ssl_enabled=ssl_enabled)
#      62     plugin_auth_response = auth.auth_response()
#      63 except (TypeError, errors.InterfaceError) as exc:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\authentication.py:190, in get_auth_plugin(plugin_name)
#     187     if authclass.plugin_name == plugin_name:
#     188         return authclass
# --> 190 raise errors.NotSupportedError(
#     191     "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %%
def tables():
    channel_table()
    videos_table()
    comments_table()
    return "Tables Created successfully"

# %%
# Function to fetch data from MySQL and return DataFrame
def fetch_data_from_mysql(query):
    mysql_conn = mysql.connector.connect(
        host="127.0.0.1",
        user="root",
        password="root",
        database="Youtube"
    )
    df = pd.read_sql(query, mysql_conn)
    mysql_conn.close()
    return df

# Function to display table in Streamlit
def display_table(table_name):
    query = f"SELECT * FROM {table_name}"
    df = fetch_data_from_mysql(query)
    st.write(f"## {table_name.capitalize()} Table")
    st.write(df)

# Main Streamlit app
def main():
    st.title("MySQL Tables Viewer")

    # List of available tables
    tables = ["channels", "videos", "comments"]

    # Select table to display
    selected_table = st.selectbox("Select Table", tables)

    # Display selected table
    display_table(selected_table)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown database 'youtube'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[169], line 34
#      31     display_table(selected_table)
#      33 if __name__ == "__main__":
# ---> 34     main()
#
# Cell In[169], line 31, in main()
#      28 selected_table = st.selectbox("Select Table", tables)
#      30 # Display selected table
# ---> 31 display_table(selected_table)
#
# Cell In[169], line 16, in display_table(table_name)
#      14 def display_table(table_name):
#      15     query = f"SELECT * FROM {table_name}"
# ---> 16     df = fetch_data_from_mysql(query)
#      17     st.write(f"## {table_name.capitalize()} Table")
#      18     st.write(df)
#
# Cell In[169], line 3, in fetch_data_from_mysql(query)
#       2 def fetch_data_from_mysql(query):
# ----> 3     mysql_conn = mysql.connector.connect(
#       4         host="127.0.0.1",
#       5         user="root",
#       6         password="root",
#       7         database="Youtube"
#       8     )
#       9     df = pd.read_sql(query, mysql_conn)
#      10     mysql_conn.close()
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection_cext.py:140, in CMySQLConnection.__init__(self, **kwargs)
#     138 if kwargs:
#     139     try:
# --> 140         self.connect(**kwargs)
#     141     except Exception:
#     142         self.close()
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\abstracts.py:1363, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1360     self.config(**kwargs)
#    1362 self.disconnect()
# -> 1363 self._open_connection()
#    1365 charset, collation = (
#    1366     kwargs.pop("charset", None),
#    1367     kwargs.pop("collation", None),
#    1368 )
#    1369 if charset or collation:
#
# File c:\Users\Admin\Desktop\Cindhu - GUVI\Youtube\.venv\lib\site-packages\mysql\connector\connection_cext.py:328, in CMySQLConnection._open_connection(self)
#     326         self.converter.str_fallback = self._converter_str_fallback
#     327 except MySQLInterfaceError as err:
# --> 328     raise get_mysql_exception(
#     329         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     330     ) from err
#     332 self._do_handshake()
#
# ProgrammingError: 1049 (42000): Unknown database 'youtube'
