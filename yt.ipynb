# %%
from googleapiclient.discovery import build
import pymongo
import mysql.connector
import cryptography
import pandas as pd
import mysql.connector as sql
import pymysql
import streamlit as st
from streamlit_option_menu import option_menu
from PIL import Image
import plotly.express as px

# %%
api_key = "AIzaSyDeNGdSiAyKWkvHmKZzNZb3yT0_xN3PmAg"
api_service_name = "youtube"
api_version = "v3"
youtube =build(api_service_name, api_version,developerKey = api_key)

# %%
def get_channel_details(c_id):
     request=youtube.channels().list(
       part="snippet,contentDetails,statistics",
       id=c_id
)
     channel_response = request.execute()
     
     for i in channel_response['items']:
           data = dict(channel_name=i['snippet']['title'],
                channel_id=i['id'],
                subscribers=i['statistics']['subscriberCount'],
                channel_views=i['statistics']['viewCount'],
                Total_videos=i['statistics']['videoCount'],
                Description=i['snippet']['description'],
                playlist_id=i['contentDetails']['relatedPlaylists']['uploads']
                )
     return data

# %%
channel_data = get_channel_details("UCQqmjKQBKQkRbWbSntYJX0Q")
channel_data
# Out:
# {'channel_name': 'Shabarinath Premlal',
#  'channel_id': 'UCQqmjKQBKQkRbWbSntYJX0Q',
#  'subscribers': '201',
#  'channel_views': '2096',
#  'Total_videos': '7',
#  'Description': '',
#  'playlist_id': 'UUQqmjKQBKQkRbWbSntYJX0Q'}

# %%
def get_video_ids(c_id):
    video_ids=[]
    response = youtube.channels().list(id=c_id,
                                    part='contentDetails').execute()
    playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page = None
    while True:
        video_response = youtube.playlistItems().list(
                                    part='snippet',
                                    playlistId=playlist_id,
                                    maxResults=50,
                                    pageToken=next_page).execute()
        for i in range(len(video_response['items'])):
            video_ids.append(video_response['items'][i]['snippet']['resourceId']['videoId'])
        next_page=video_response.get('nextPageToken')
        if next_page is None:
            break
    return video_ids

# %%
v_id=get_video_ids('UCQqmjKQBKQkRbWbSntYJX0Q')

# %%
v_id
# Out:
# ['aYuCM7hHPAQ',
#  'Yndu_cdyDng',
#  'X45N3h7b_5I',
#  'CPO7xgstK0Q',
#  'DGbSMC8AoH4',
#  'rdRAdvsESKA',
#  'mvEaWBYmFqI']

# %%
def get_video_details(V_ID):
    video_data=[]
    for video_id in V_ID:
        v_request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        v_response=v_request.execute()
        for item in v_response["items"]:
                                    data=dict(
                                            Video_Id=item['id'],
                                            Vide_name=item['snippet']['title'],
                                            Tags=item['snippet'].get('tags'),
                                            Description=item['snippet'].get('description'),
                                            PublishedAt=item['snippet']['publishedAt'],
                                            Thumbnail=item['snippet']['thumbnails']['default']['url'],
                                            Duration=item['contentDetails']['duration'],
                                            Views_count=item['statistics'].get('viewCount'),
                                            Likes_count=item['statistics'].get('likeCount'),
                                            Comments_count=item['statistics'].get('commentCount'),
                                            Favorite_Count=item['statistics']['favoriteCount'],
                                            Definition=item['contentDetails']['definition'],
                                            Caption_Status=item['contentDetails']['caption']
                                            )
                                    video_data.append(data)    
    return video_data

# %%
v_details = get_video_details(v_id)

# %%
v_details
# Out:
# [{'Video_Id': 'aYuCM7hHPAQ',
#   'Vide_name': 'Turn every setback into a comeback video',
#   'Tags': None,
#   'Description': 'we ll have regular technical updates\n#comeback  #setback',
#   'PublishedAt': '2023-08-28T16:37:46Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/aYuCM7hHPAQ/default.jpg',
#   'Duration': 'PT55S',
#   'Views_count': '297',
#   'Likes_count': '32',
#   'Comments_count': '13',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'Yndu_cdyDng',
#   'Vide_name': 'Intro about python and Google Colab',
#   'Tags': None,
#   'Description': "Python is an interpreted high-level general-purpose programming language. Python's design philosophy emphasizes code readability with its notable use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.\n\nColaboratory, or “Colab” for short, is a product from Google Research. Colab allows anybody to write and execute arbitrary python code through the browser, and is especially well suited to machine learning, data analysis and education.\n\n#ML\u200b #AI\u200b #DL\u200b #python #colab #google\n#MachineLearning\u200b #DeepLearning\u200b #ArtificialIntelligence\u200b #Embedded\u200b #Machine\u200b #Tamil\u200b #Chennai\u200b #TamilNadu\u200b #Technology\u200b\n#Mathematics\u200b #Humans\u200b #Brain\u200b #NuralNetwork\u200b  #Nature\u200b #Python\u200b #R\u200b \n\n\nIntroduction about Machine in Machine Learning in Tamil\nhttps://www.youtube.com/watch?v=rdRAd...\u200b\n\nIntroduction about Learning Process in Machine (Machine Learning) in Tamil\nhttps://www.youtube.com/watch?v=DGbSM\u200b...\n\nDoes human brain are good in mathematics , patterns, predictive analysis ?\nhttps://www.youtube.com/watch?v=CPO7x...\n\nMathematics reveals hidden patterns that help us understand the world around us.\nhttps://www.youtube.com/watch?v=X45N3h7b_5I",
#   'PublishedAt': '2021-05-08T14:25:05Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/Yndu_cdyDng/default.jpg',
#   'Duration': 'PT11M25S',
#   'Views_count': '149',
#   'Likes_count': '6',
#   'Comments_count': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'X45N3h7b_5I',
#   'Vide_name': 'Mathematics reveals hidden patterns that help us understand the world around us.',
#   'Tags': None,
#   'Description': 'Mathematics reveals hidden patterns that help us understand the world around us. Now much more than arithmetic and geometry, mathematics today is a diverse discipline that deals with data, measurements, and observations from science; with inference, deduction, and proof; and with mathematical models of natural phenomena, of human behavior, and of social systems.\n\nAs a practical matter, mathematics is a science of pattern and order. Its domain is not molecules or cells, but numbers, chance, form, algorithms, and change.\n\n#ML #AI #DL\n#MachineLearning #DeepLearning #ArtificialIntelligence #Embedded #Machine #Tamil #Chennai #TamilNadu #Technology\n#Mathematics #Humans #Brain #NuralNetwork  #Nature #Python #R \n\n\nIntroduction about Machine in Machine Learning in Tamil\nhttps://www.youtube.com/watch?v=rdRAd...\u200b\n\nIntroduction about Learning Process in Machine (Machine Learning) in Tamil\nhttps://www.youtube.com/watch?v=DGbSM...\n\nDoes human brain are good in mathematics , patterns, predictive analysis ?\nhttps://www.youtube.com/watch?v=CPO7xgstK0Q',
#   'PublishedAt': '2021-04-30T15:14:42Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/X45N3h7b_5I/default.jpg',
#   'Duration': 'PT8M32S',
#   'Views_count': '361',
#   'Likes_count': '29',
#   'Comments_count': '5',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'CPO7xgstK0Q',
#   'Vide_name': 'Does human brain are good in mathematics , patterns, predictive analysis ?',
#   'Tags': None,
#   'Description': 'Technology in Tamil : The body of knowledge and practice known as mathematics is derived from the contributions of thinkers throughout the ages and across the globe. It gives us a way to understand patterns, to quantify relationships, to predict the future, reasoning, creativity, abstract or spatial thinking, critical thinking, problem-solving ability and even effective communication skills. Math helps us understand the world — and we use the world to understand math.\n\n#ML #AI #DL\n#MachineLearning #DeepLearning #ArtificialIntelligence #Embedded #Machine #Tamil #Chennai #TamilNadu #Technology\n#Mathematics #Humans #Brain #NuralNetwork #DataScence #pattern \n\nIntroduction about Machine in Machine Learning in Tamil\nhttps://www.youtube.com/watch?v=rdRAdvsESKA&t=36s\n\nIntroduction about Learning Process in Machine (Machine Learning) in Tamil\nhttps://www.youtube.com/watch?v=DGbSMC8AoH4&t=1s',
#   'PublishedAt': '2021-04-23T14:01:05Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/CPO7xgstK0Q/default.jpg',
#   'Duration': 'PT10M43S',
#   'Views_count': '231',
#   'Likes_count': '13',
#   'Comments_count': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'DGbSMC8AoH4',
#   'Vide_name': 'Introduction about Learning Process in Machine (Machine Learning) in Tamil',
#   'Tags': None,
#   'Description': 'Introduction about Learning Process in Machine in Tamil\nTechnology in Tamil : Machine learning is a method of data analysis that automates analytical model building. Machine learning allows computers to learn and infer from data.\n\n\n#ML #AI #DL\n#MachineLearning #DeepLearning #ArtificialIntelligence #Embedded #Machine #Tamil #Chennai #TamilNadu #Technology',
#   'PublishedAt': '2021-04-19T14:21:35Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/DGbSMC8AoH4/default.jpg',
#   'Duration': 'PT13M55S',
#   'Views_count': '222',
#   'Likes_count': '15',
#   'Comments_count': '2',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'rdRAdvsESKA',
#   'Vide_name': 'Introduction about Machine in Machine Learning in Tamil',
#   'Tags': None,
#   'Description': 'Technology in Tamil : A machine is a man-made device that uses power to apply forces and control movement to perform an action. Machine learning is an application of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed.\n\n#ML #AI #DL\n#MachineLearning #DeepLearning #ArtificialIntelligence #Embedded #Machine #Tamil #Chennai #TamilNadu #Technology',
#   'PublishedAt': '2021-04-16T12:16:53Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/rdRAdvsESKA/default.jpg',
#   'Duration': 'PT13M48S',
#   'Views_count': '387',
#   'Likes_count': '34',
#   'Comments_count': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Video_Id': 'mvEaWBYmFqI',
#   'Vide_name': 'Introduction to technology in Tamil',
#   'Tags': None,
#   'Description': 'Technology in Tamil : How people can use technology like Machine Learning, Deep Learning, Artificial Intelligence, Data Science, NLP etc to enhance the skills, methods, and processes used to achieve goals in in His/Her career.\n\n#ML #DL #AI #MachineLearning #DeepLearning #ArtificialIntelligence #DataScience #NLP #Trading #AlgoTrading',
#   'PublishedAt': '2021-04-14T14:19:21Z',
#   'Thumbnail': 'https://i.ytimg.com/vi/mvEaWBYmFqI/default.jpg',
#   'Duration': 'PT2M57S',
#   'Views_count': '449',
#   'Likes_count': '32',
#   'Comments_count': '5',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
def get_comment_details(co_ids):
    comment_data=[]
    try:
        for co_id  in co_ids:
                            c_request=youtube.commentThreads().list(
                                part="snippet",
                                videoId=co_id,
                                maxResults=50
                            )
                            c_response=c_request.execute()

                            for item in c_response['items']:
                                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                                comment_data.append(data)                         
    except:
        pass

    return comment_data

# %%
c_details = get_comment_details(v_id)

# %%
c_details
# Out:
# [{'Comment_Id': 'Ugz5jHKmK74P7AYjklx4AaABAg',
#   'Comment_Text': 'Hai bro how are you ? your way of explanation and given live examples are easy way to understand the technology your teaching methodology is awesome congratulations 🎉',
#   'Comment_Author': '@renugadevichakkarai6111',
#   'Comment_Published': '2024-02-09T09:03:48Z'},
#  {'Comment_Id': 'UgxEQtw9lQ5HNAIladV4AaABAg',
#   'Comment_Text': 'Ayyaa',
#   'Comment_Author': '@dineeshvarshanc1576',
#   'Comment_Published': '2023-09-08T15:02:31Z'},
#  {'Comment_Id': 'UgxWCAzRbu7XnkS6DD94AaABAg',
#   'Comment_Text': 'Waiting for your videos big boss 🎉',
#   'Comment_Author': '@PraveenN-fp5jy',
#   'Comment_Published': '2023-09-04T18:59:03Z'},
#  {'Comment_Id': 'Ugx_McuXDnVPw4PS-Ix4AaABAg',
#   'Comment_Text': 'Congrats 👏',
#   'Comment_Author': '@thineshkumar5068',
#   'Comment_Published': '2023-08-31T06:15:49Z'},
#  {'Comment_Id': 'UgyxKbaURKGmmbZoYMB4AaABAg',
#   'Comment_Text': 'Congratulations Shabari,we are waiting...',
#   'Comment_Author': '@cinemashots3903',
#   'Comment_Published': '2023-08-29T07:45:54Z'},
#  {'Comment_Id': 'UgxWRFKMs5mGY10tESB4AaABAg',
#   'Comment_Text': 'waiting sir......',
#   'Comment_Author': '@NGStudio1997',
#   'Comment_Published': '2023-08-29T06:22:54Z'},
#  {'Comment_Id': 'UgwQLnOsfJCIpAI45sh4AaABAg',
#   'Comment_Text': 'Congratulations 🎉<br>Eagerly waiting for yours.......',
#   'Comment_Author': '@Uk-zen',
#   'Comment_Published': '2023-08-29T06:13:31Z'},
#  {'Comment_Id': 'UgybIC5X4aNoPVBMBKt4AaABAg',
#   'Comment_Text': 'Waiting for yours sessions sir 😊',
#   'Comment_Author': '@rabinanto07',
#   'Comment_Published': '2023-08-28T18:42:59Z'},
#  {'Comment_Id': 'UgxMT8PuAPl_cPOf0O94AaABAg',
#   'Comment_Text': 'That&#39;s really a good initiative shabari, congratulations and thanks for taking up our feedback seriously, will support you for sure ...<a href="UCkszU2WH9gy1mb0dV-11UJg/Iv90XouTLuOR8gSxxrToBA"></a>',
#   'Comment_Author': '@iampraveens',
#   'Comment_Published': '2023-08-28T18:38:32Z'},
#  {'Comment_Id': 'UgxhjKjKXpnYKtXZH_14AaABAg',
#   'Comment_Text': 'Hi sir, santhiya(DT1) waiting for ur videos....need a clear cut explanation in tamil for generative ai,nlp etc..thank u<a href="UCkszU2WH9gy1mb0dV-11UJg/EvkfY6uNC5OykQOewoCQAQ"></a>',
#   'Comment_Author': '@NidhisVlog',
#   'Comment_Published': '2023-08-28T16:42:24Z'},
#  {'Comment_Id': 'UgzC3Yv-ZT40K9gGnVh4AaABAg',
#   'Comment_Text': '✌',
#   'Comment_Author': '@tamilfreefirememes6579',
#   'Comment_Published': '2024-02-20T16:52:12Z'},
#  {'Comment_Id': 'UgwHoX5qPDu6TEA3YVh4AaABAg',
#   'Comment_Text': 'sir how to contact yu',
#   'Comment_Author': '@nikhilesh3683',
#   'Comment_Published': '2022-02-24T15:34:42Z'},
#  {'Comment_Id': 'UgyVXmqjddv-uzMFhiV4AaABAg',
#   'Comment_Text': 'hats-off to your effort to make everyone to understand the concept in a live demo, really  awesome sir. we are waiting for the coding session too.',
#   'Comment_Author': '@santhoshnagaraj344',
#   'Comment_Published': '2021-09-05T15:28:38Z'},
#  {'Comment_Id': 'UgwkIoV-Idj85tk7fQJ4AaABAg',
#   'Comment_Text': 'Nice try Shabari.',
#   'Comment_Author': '@jshari2002',
#   'Comment_Published': '2021-05-25T11:15:32Z'},
#  {'Comment_Id': 'Ugw2Y1bNZ3JKOaUJSzt4AaABAg',
#   'Comment_Text': 'Informative speech....superb...',
#   'Comment_Author': '@gowrishankaris9169',
#   'Comment_Published': '2021-05-22T12:41:07Z'},
#  {'Comment_Id': 'Ugx3lp9tlIY9bKLiZN54AaABAg',
#   'Comment_Text': 'Waiting for coding part 🔥',
#   'Comment_Author': '@outplays_3',
#   'Comment_Published': '2021-05-02T11:57:37Z'},
#  {'Comment_Id': 'UgxHyoFPleWtRruxE2x4AaABAg',
#   'Comment_Text': 'Can we drive the autonomous car and make it to learn the data&#39;s  of our own method of driving by the machine and completing the training let it be drive autonomously. or we have to give the data feeding as datasets to it and work for it ? or both methodology is needed to achieve it?',
#   'Comment_Author': '@santhoshnagaraj344',
#   'Comment_Published': '2021-09-05T15:14:44Z'},
#  {'Comment_Id': 'UgxZnRojiA2YEKbjGLh4AaABAg',
#   'Comment_Text': 'Good attempt. Keep it up',
#   'Comment_Author': '@jaggujayanth',
#   'Comment_Published': '2021-04-28T10:17:46Z'},
#  {'Comment_Id': 'UgyYcUf7GbE5iVpLU5R4AaABAg',
#   'Comment_Text': 'Hello sir iam having an doubt on ardunio and nodemcu. How can i use golang to control io pins  in above mentioned boards.',
#   'Comment_Author': '@outplays_3',
#   'Comment_Published': '2021-04-24T04:54:24Z'},
#  {'Comment_Id': 'UgxEFbsnvv607CVmGLR4AaABAg',
#   'Comment_Text': 'Awesome explanation sir',
#   'Comment_Author': '@madhanmohan1634',
#   'Comment_Published': '2023-02-17T19:08:23Z'},
#  {'Comment_Id': 'UgzfHnE7I-iMDqE9OSZ4AaABAg',
#   'Comment_Text': 'sir, is there is all the algorithms to be trained for the machine to mimic as like human or to train particular set of algorithms are enough to mimic like human.',
#   'Comment_Author': '@santhoshnagaraj344',
#   'Comment_Published': '2021-09-05T14:51:25Z'},
#  {'Comment_Id': 'Ugz0ISPai5Io9pVOof54AaABAg',
#   'Comment_Text': 'Already one Mr.Magesh of RESPRO Capital management was put behind the bars for almost 3 crore fraud... this fraud will also be caught sooner',
#   'Comment_Author': '@Greenome',
#   'Comment_Published': '2023-12-11T05:40:09Z'},
#  {'Comment_Id': 'UgzX-83ZjuBaVLSK5-d4AaABAg',
#   'Comment_Text': 'A criminal case on money scam has been filed against him already... soon he will be behind the bars',
#   'Comment_Author': '@Greenome',
#   'Comment_Published': '2023-12-11T05:39:07Z'},
#  {'Comment_Id': 'UgyDv_s5aGKfgUZxzqx4AaABAg',
#   'Comment_Text': 'Fraud to the core he is... he runs a company called RESPRO Capital management through which he gets funds from others and cheats ... Do not believe him.. he doesnt know even 9th standard mathematics properly... all he does his in the name of data science , he cheats people.. he is not a PHD .. he was not even a properly qualified engineer',
#   'Comment_Author': '@Greenome',
#   'Comment_Published': '2023-12-11T05:37:34Z'},
#  {'Comment_Id': 'UgwIEMkpFfV09f2FtKV4AaABAg',
#   'Comment_Text': 'its awesome to learn AI in native language(Tamil) and your teaching and examples are amazing everyone can understand the concept. :)',
#   'Comment_Author': '@santhoshnagaraj344',
#   'Comment_Published': '2021-09-05T14:36:30Z'},
#  {'Comment_Id': 'UgzKOhlF0OfyQaB6TSx4AaABAg',
#   'Comment_Text': 'Great to learn in tamil..<br>👌😎',
#   'Comment_Author': '@shanmugapriya.v430',
#   'Comment_Published': '2021-04-16T17:16:27Z'},
#  {'Comment_Id': 'UgxUdQOXlO6Vq_Wr2A54AaABAg',
#   'Comment_Text': 'Super Sir.. Explanation and examples given for that are exemplary.',
#   'Comment_Author': '@giridharanr135',
#   'Comment_Published': '2021-04-16T14:08:34Z'},
#  {'Comment_Id': 'UgwL0rGruAmMcd1zwjx4AaABAg',
#   'Comment_Text': 'Hi sir unga kitta online class padika mudiuma',
#   'Comment_Author': '@lakshmilakshmi550',
#   'Comment_Published': '2024-02-16T07:53:29Z'},
#  {'Comment_Id': 'UgxLT85vFnDRI88eFNd4AaABAg',
#   'Comment_Text': '🔥',
#   'Comment_Author': '@ranch_03',
#   'Comment_Published': '2023-02-28T14:25:57Z'},
#  {'Comment_Id': 'UgzUplBxDTHLXMYOScV4AaABAg',
#   'Comment_Text': '🔥',
#   'Comment_Author': '@outplays_3',
#   'Comment_Published': '2021-04-15T05:06:57Z'},
#  {'Comment_Id': 'Ugy4osqlQNY4Fo77hFR4AaABAg',
#   'Comment_Text': 'Good effort Shabari Sir. Keep going 👍',
#   'Comment_Author': '@diwakarang1316',
#   'Comment_Published': '2021-04-15T04:02:38Z'}]

# %%
c_obj=pymongo.MongoClient("mongodb://cindhu10:guvi2024@ac-8q7snle-shard-00-00.bw8cuhe.mongodb.net:27017,ac-8q7snle-shard-00-01.bw8cuhe.mongodb.net:27017,ac-8q7snle-shard-00-02.bw8cuhe.mongodb.net:27017/?ssl=true&replicaSet=atlas-6n6ftf-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")
db=c_obj["Youtube_data"]

# %%
def channel_details(ch_id):
    c_details=get_channel_details(ch_id)
    vi_id=get_video_ids(ch_id)
    v_details=get_video_details(vi_id)
    com_details=get_comment_details(vi_id)

    collect=db["channel_details"]
    collect.insert_one({"channel_documents":c_details,
                      "video_documents":v_details,"comment_documents":com_details})
    
    return "uploaded successfully"

# %%
coll = channel_details("UCQqmjKQBKQkRbWbSntYJX0Q")
coll
# Out:
# 'uploaded successfully'

# %%
mydb = sql.connect(host="127.0.0.1",
                   user="root@localhost",
                   password="root@123",
                   database= "Youtube",
                   port = "3306"
                  )
mycursor = mydb.cursor(buffered=True)

# %%
with st.sidebar:
    selected = option_menu(None, ["Home","Extract ","View"], 
                           icons=["house-door-fill","tools","card-text"],
                           default_index=0,
                           orientation="vertical",
                           styles={"nav-link": {"font-size": "30px", "text-align": "centre", "margin": "0px", 
                                                "--hover-color": "#33A5FF"},
                                   "icon": {"font-size": "30px"},
                                   "container" : {"max-width": "6000px"},
                                   "nav-link-selected": {"background-color": "#33A5FF"}})


if selected == "Home":
    col1,col2 = st.columns(2,gap= 'medium')
    col1.markdown("## :blue[Domain] : Social Media")
    col1.markdown("## :blue[Technologies used] : Python,MongoDB, Youtube Data API, MySql, Streamlit")
    col1.markdown("## :blue[Overview] : Retrieving the Youtube channels data from the Google API, storing it in a MongoDB as data lake, migrating and transforming data into a SQL database,then querying the data and displaying it in the Streamlit app.")
    col2.markdown("#   ")
    col2.markdown("#   ")
    col2.markdown("#   ")


if selected == "Extract":
    tab1,tab2 = st.tabs(["$\medium  EXTRACT "])
    
    
    with tab1:
        st.markdown("#    ")
        st.write("### Enter YouTube Channel_ID below :")
        ch_id = st.text_input("Hint : Goto channel's home page > Right click > View page source > Find channel_id").split(',')

        if ch_id and st.button("Extract Data"):
            ch_details = get_channel_details(ch_id)
            st.write(f'#### Extracted data from :green["{ch_details[0]["Channel_name"]}"] channel')
            st.table(ch_details)

        if st.button("Upload to MongoDB"):
            with st.spinner('Please Wait for it...'):
                c_details = get_channel_details(ch_id)
                v_id = get_video_ids(ch_id)
                vid_details = get_video_details(v_id)
                
                def comments():
                    com_d = []
                    for i in v_id:
                        com_d+= get_comment_details(i)
                    return com_d
                comm_details = comments()

                collections1 = db.channel_details
                collections1.insert_many(c_details)

                collections2 = db.video_details
                collections2.insert_many(vid_details)

                collections3 = db.comments_details
                collections3.insert_many(comm_details)
                st.success("Upload to MongoDB successful !!")
      

    with tab2:     
            st.markdown("#   ")
            st.markdown("### Select a channel to begin Transformation to SQL")
            ch_names = channel_details()  
            user_inp = st.selectbox("Select channel",options= ch_names)
        
    def insert_into_channels():
                    collections = db.channel_details
                    query = """INSERT INTO channels VALUES(%s,%s,%s,%s,%s,%s,%s,%s)"""
                
                    for i in collections.find({"channel_name" : user_inp},{'_id' : 0}):
                        mycursor.execute(query,tuple(i.values()))
                    mydb.commit()
                
    def insert_into_videos():
            collections1 = db.video_details
            query1 = """INSERT INTO videos VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

            for i in collections1.find({"channel_name" : user_inp},{'_id' : 0}):
                values = [str(val).replace("'", "''").replace('"', '""') if isinstance(val, str) else val for val in i.values()]
                mycursor.execute(query1, tuple(values))
                mydb.commit()

    def insert_into_comments():
            collections1 = db.video_details
            collections2 = db.comments_details
            query2 = """INSERT INTO comments VALUES(%s,%s,%s,%s,%s,%s,%s)"""

            for vid in collections1.find({"channel_name" : user_inp},{'_id' : 0}):
                for i in collections2.find({'Video_id': vid['Video_id']},{'_id' : 0}):
                    mycursor.execute(query2,tuple(i.values()))
                    mydb.commit()

    if st.button("Submit"):
        try:
            insert_into_videos()
            insert_into_channels()
            insert_into_comments()
            st.success("Transformation to MySQL Successful !!")
        except:
            st.error("Channel details already transformed !!")

# %%
if selected == "View":
    
    st.write("## :orange[Select any question to get Insights]")
    questions = st.selectbox('Questions',
    ['1. What are the names of all the videos and their corresponding channels?',
    '2. Which channels have the most number of videos, and how many videos do they have?',
    '3. What are the top 10 most viewed videos and their respective channels?',
    '4. How many comments were made on each video, and what are their corresponding video names?',
    '5. Which videos have the highest number of likes, and what are their corresponding channel names?',
    '6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?',
    '7. What is the total number of views for each channel, and what are their corresponding channel names?',
    '8. What are the names of all the channels that have published videos in the year 2022?',
    '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?',
    '10. Which videos have the highest number of comments, and what are their corresponding channel names?'])
    
    if questions == '1. What are the names of all the videos and their corresponding channels?':
        mycursor.execute("""SELECT Video_name AS Video_name, channel_name AS Channel_Name
                            FROM videos
                            ORDER BY channel_name""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
    elif questions == '2. Which channels have the most number of videos, and how many videos do they have?':
            mycursor.execute("""SELECT channel_name AS Channel_Name, total_videos AS Total_Videos
                                FROM channels
                                ORDER BY total_videos DESC""")
            df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
            st.write(df)
            st.write("### :green[Number of videos in each channel :]")
            #st.bar_chart(df,x= mycursor.column_names[0],y= mycursor.column_names[1])
            fig = px.bar(df,
                        x=mycursor.column_names[0],
                        y=mycursor.column_names[1],
                        orientation='v',
                        color=mycursor.column_names[0]
                        )
            st.plotly_chart(fig,use_container_width=True)
    elif questions == '3. What are the top 10 most viewed videos and their respective channels?':
        mycursor.execute("""SELECT channel_name AS Channel_Name, Video_name AS Video_Title, View_count AS Views 
                            FROM videos
                            ORDER BY views DESC
                            LIMIT 10""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        st.write("### :green[Top 10 most viewed videos :]")
        fig = px.bar(df,
                     x=mycursor.column_names[2],
                     y=mycursor.column_names[1],
                     orientation='h',
                     color=mycursor.column_names[0]
                    )
        st.plotly_chart(fig,use_container_width=True)
    elif questions == '4. How many comments were made on each video, and what are their corresponding video names?':
        mycursor.execute("""SELECT a.video_id AS Video_id, Video_name AS Video_Title, b.Total_Comments
                            FROM videos AS a
                            LEFT JOIN (SELECT video_id,COUNT(comment_id) AS Total_Comments
                            FROM comments GROUP BY video_id) AS b
                            ON a.video_id = b.video_id
                            ORDER BY b.Total_Comments DESC""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
          
    elif questions == '5. Which videos have the highest number of likes, and what are their corresponding channel names?':
        mycursor.execute("""SELECT channel_name AS Channel_Name,Video_name AS Title,Like_count AS Like_Count 
                            FROM videos
                            ORDER BY Like_count DESC
                            LIMIT 10""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        st.write("### :green[Top 10 most liked videos :]")
        fig = px.bar(df,
                     x=mycursor.column_names[2],
                     y=mycursor.column_names[1],
                     orientation='h',
                     color=mycursor.column_names[0]
                    )
        st.plotly_chart(fig,use_container_width=True)
        
    elif questions == '6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?':
        mycursor.execute("""SELECT Video_name AS Title, Like_count AS Like_count
                            FROM videos
                            ORDER BY Like_count DESC""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
         
    elif questions == '7. What is the total number of views for each channel, and what are their corresponding channel names?':
        mycursor.execute("""SELECT channel_name AS Channel_Name, channel_views AS Views
                            FROM channels
                            ORDER BY views DESC""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        st.write("### :green[Channels vs Views :]")
        fig = px.bar(df,
                     x=mycursor.column_names[0],
                     y=mycursor.column_names[1],
                     orientation='v',
                     color=mycursor.column_names[0]
                    )
        st.plotly_chart(fig,use_container_width=True)
        
    elif questions == '8. What are the names of all the channels that have published videos in the year 2022?':
        mycursor.execute("""SELECT channel_name AS Channel_Name
                            FROM videos
                            WHERE published_date LIKE '2022%'
                            GROUP BY channel_name
                            ORDER BY channel_name""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        
    elif questions == '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?':
        mycursor.execute("""SELECT channel_name AS Channel_Name,
                            AVG(duration)/60 AS "Average_Video_Duration (mins)"
                            FROM videos
                            GROUP BY channel_name
                            ORDER BY AVG(duration)/60 DESC""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        st.write("### :green[Avg video duration for channels :]")
        fig = px.bar(df,
                     x=mycursor.column_names[0],
                     y=mycursor.column_names[1],
                     orientation='v',
                     color=mycursor.column_names[0]
                    )
        st.plotly_chart(fig,use_container_width=True)
        
    elif questions == '10. Which videos have the highest number of comments, and what are their corresponding channel names?':
        mycursor.execute("""SELECT channel_name AS Channel_Name,Video_id AS Video_ID,Comment_count AS Comments
                            FROM videos
                            ORDER BY comments DESC
                            LIMIT 10""")
        df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
        st.write(df)
        st.write("### :green[Videos with most comments :]")
        fig = px.bar(df,
                     x=mycursor.column_names[1],
                     y=mycursor.column_names[2],
                     orientation='v',
                     color=mycursor.column_names[0]
                    )
        st.plotly_chart(fig,use_container_width=True)
